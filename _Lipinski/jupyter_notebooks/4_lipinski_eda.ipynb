# %% [markdown]
# # Exploratory Data Analysis - Lipinksi's rule for the FDA New Chemical Entities (1997-2021)

# %% [markdown]
# After manually curated the dataset (merged from FDA database and DrugBank database) we are going the explore the Lipinski's rules of the ~560 New Chemical Entitities approved by the <b>FDA</b>. About 30 SMILES were manually gathered since none of the two strategies worked (SMILES from name structures or automatically merged with the DrugBank database).
#
# First we need to import the libraries used in this analysis, which is mainly composed of rdkit (to manipulate the structures) and pandas/searborn to do the data analysis.

# %%
from rdkit import Chem, rdBase
from rdkit.Chem import Draw, Descriptors, PandasTools, AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.SaltRemover import SaltRemover, InputFormat

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Loading the and treating the dataset

# %% [markdown]
# Now, we load the database in the xlsx format. The database was converted to excel and carefully curated: each of the SMILES double checked, most  of the salts removed and was done by GHMS and ACGS.

# %%
# We read the raw data
drugs = pd.read_csv("https://raw.githubusercontent.com/arturcgs/shared-side-projects/main/_Lipinski/data/manually_curated_datasets/fda_small_molecules_smiles.csv")

# Selecting the dataframe without the index that came from the excel file
drugs = drugs.iloc[:,1:]
drugs.head(3)
# Out:
#    active_ingredient_moiety nda_bla  approval_year        active DrugBank ID  \
# 0              troglitazone     NDA           1997  troglitazone     DB00197
# 1                 imiquimod     NDA           1997     imiquimod     DB00724
# 2  anagrelide hydrochloride     NDA           1997    anagrelide     DB00261
#
#                             Drug Groups  \
# 0  approved; investigational; withdrawn
# 1             approved; investigational
# 2                              approved
#
#                                               SMILES          Name  \
# 0  CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...  Troglitazone
# 1                 CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N     Imiquimod
# 2                    ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl    Anagrelide
#
#            Drug Type
# 0  SmallMoleculeDrug
# 1  SmallMoleculeDrug
# 2  SmallMoleculeDrug

# %%
drugs[(drugs["SMILES"] == "Not found")]
# Out:
#                           active_ingredient_moiety nda_bla  approval_year  \
# 533                      colesevelam hydrochloride     NDA           2000
# 535                              tinzaparin sodium     NDA           2000
# 545                                  kunecatechins     NDA           2006
# 548                         gadofosveset trisodium     NDA           2008
# 550                                     crofelemer     NDA           2012
# 554  sulfur hexafluoride lipid-type A microspheres     NDA           2014
# 555                                      patiromer     NDA           2015
# 557                 sodium zirconium cyclosilicate     NDA           2018
#
#                                             active DrugBank ID  \
# 533                                    colesevelam     DB00930
# 535                                     tinzaparin     DB06822
# 545                                  kunecatechins     DB01266
# 548                                   gadofosveset     DB06705
# 550                                     crofelemer     DB04941
# 554  sulfur hexafluoride lipid-type A microspheres     DB11104
# 555                                      patiromer     DB09263
# 557                        zirconium cyclosilicate     DB14048
#
#                             Drug Groups     SMILES  \
# 533                            approved  Not found
# 535                            approved  Not found
# 545                       nutraceutical  Not found
# 548                            contrast  Not found
# 550                   approved; polymer  Not found
# 554                            approved  Not found
# 555  approved; investigational; polymer  Not found
# 557                            approved  Not found
#
#                                Name          Drug Type
# 533                     Colesevelam  SmallMoleculeDrug
# 535                      Tinzaparin  SmallMoleculeDrug
# 545                   Sinecatechins  SmallMoleculeDrug
# 548          Gadofosveset trisodium  SmallMoleculeDrug
# 550                      Crofelemer  SmallMoleculeDrug
# 554             Sulfur hexafluoride  SmallMoleculeDrug
# 555                       Patiromer  SmallMoleculeDrug
# 557  Sodium zirconium cyclosilicate  SmallMoleculeDrug

# %% [markdown]
# ### 1.1) Initial cleaning and prep

# %% [markdown]
# First, we need to do some cleaning job on the dataset. We need to remove some of the salts  and do some double checking on the stuff. Now we perform the <b>SALT CLEANING</b> and the deionization of the respective base.
#
# We begin by converting the SMILES into the mol format for further analysis

# %%
# Removing the "Not Found" SMILES. The SMILES were almost all manually curated in order to gather as many structures as possible
drugs_db = drugs.loc[~(drugs["SMILES"] == "Not found")]
print(drugs_db.shape)
# Adding the ROMol Column, which is the proper format (mol) for further calculations
PandasTools.AddMoleculeColumnToFrame(drugs_db, "SMILES")
# Out:
# (552, 9)
# [18:56:22] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [18:56:22] Explicit valence for atom # 0 N, 4, is greater than permitted
# [18:56:22] Explicit valence for atom # 10 S, 7, is greater than permitted
# RDKit ERROR: [18:56:22] Explicit valence for atom # 10 S, 7, is greater than permitted
# /home/gustavo/miniconda3/envs/teachopencadd/lib/python3.8/site-packages/rdkit/Chem/PandasTools.py:422: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)

# %% [markdown]
# Then, we make a function to clean the salts from the database. The selected ions were Cl, Br, Na, K and Gd (mainly from contrast structures)

# %%
# defining the salts we want to remove from the database
remover = SaltRemover(defnData="[Cl,Br,Na,K,Gd]")

# Defining the function to neutralize the atoms in organic molecules
def neutralize_atoms(mol):
    pattern = Chem.MolFromSmarts("[+1!h0!$([*]~[-1,-2,-3,-4]),-1!$([*]~[+1,+2,+3,+4])]")
    at_matches = mol.GetSubstructMatches(pattern)
    at_matches_list = [y[0] for y in at_matches]
    if len(at_matches_list) > 0:
        for at_idx in at_matches_list:
            atom = mol.GetAtomWithIdx(at_idx)
            chg = atom.GetFormalCharge()
            hcount = atom.GetTotalNumHs()
            atom.SetFormalCharge(0)
            atom.SetNumExplicitHs(hcount - chg)
            atom.UpdatePropertyCache()
    return mol

# %% [markdown]
# In order to advance into the curation process we need to remove any non-readable or innappropriate smile/structure. We can do this and simutaneously stripping the salts using the function `StripMol()` that uses the `remover.SaltRemover()` function defined earlier.

# %%
mols = [] # creating an empty list

## FUNCTION FOR CHECKING THE NON READABLE:

# Creating a loop to 1) convert from smiles to mol and use the `remover.StripMol() on each structure
for i, smi in enumerate(drugs_db.SMILES):
    try:
        mol = Chem.MolFromSmiles(smi) # converting to a proper format
        mol = remover.StripMol(mol) # stripping the salts
        mols.append(mol) # appending to a list
    except:
        print(smi,i) # printing the exceptions, or the non-readable smiles and the respective index
# Out:
# [H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[Pt]11OC(=O)C(=O)O1 124
# CCN(CC1=CC(=CC=C1)S(=O)(=O)(=O))C2=CC(=C(C=C2)/C(=C/3\C=CC(=[N+](CC)CC4=CC(=CC=C4)S(=O)(=O)(=O))C=C3C)/C5=CC=C(C=C5)NC6=CC=C(C=C6)OCC)C 551
# RDKit ERROR: [18:56:33] Explicit valence for atom # 0 N, 4, is greater than permitted
# [18:56:33] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [18:56:33] Explicit valence for atom # 10 S, 7, is greater than permitted
# [18:56:33] Explicit valence for atom # 10 S, 7, is greater than permitted

# %% [markdown]
# We can see that our database has some non-readable smiles that can cause some problems further in the future. We can remove the by doing the `drop()` method allied to `.index[]`.

# %%
# dropping the structures found to be non-readable
drugs_db = drugs_db.drop([drugs_db.index[124],drugs_db.index[551]]).reset_index()

# %% [markdown]
# We can check again to see if any of the non-readable smiles still lingers on our dataset:

# %%
# Running the same function again (it's better to define a function and just call it again...)
mols = []
for i, smi in enumerate(drugs_db.SMILES):
    try:
        mol = Chem.MolFromSmiles(smi)
        mol = remover.StripMol(neutralize_atoms(mol))
        mols.append(mol)
    except:
        print(smi,i)

# %% [markdown]
# Since there is no structure printed, we can conclude that all the smiles left can be properly converted to mol. We are now able to perform the `remover.StripMol()` and `neutralize_atoms()` at our .mol column,

# %% [markdown]
# ### 1.2) Removing the salts and neutralizing the organic molecules

# %% [markdown]
# Using the `apply` method on the column and performing the functions `StripMol` and `neutralize_atoms`

# %%
# removing the salts
drugs_db["Mol_Clean"] = drugs_db.ROMol.apply(remover.StripMol)

# neutralizing atoms O- goes to OH and so on..
drugs_db["Mol_Clean"] = drugs_db.Mol_Clean.apply(neutralize_atoms)

# %% [markdown]
# ### 1.3) Calculation of the descriptors

# %% [markdown]
# We can see that our method cannot handle to much inorganic information such as the case of talc. Printing the structure we can see:

# %%
drugs_db.Mol_Clean[31]

# %% [markdown]
# Now we calculate the descritptors: Molecular Weight, Number of Hydrogen Acceptors, Number of Hydrogen Donors and LogP that we need to compute the statistcs of the drugs. But first we need to transform the smiles to "mol" format.

# %%
drugs_db["mw"] = drugs_db["Mol_Clean"].apply(Descriptors.ExactMolWt)
drugs_db["n_hba"] = drugs_db["Mol_Clean"].apply(Descriptors.NumHAcceptors)
drugs_db["n_hbd"] = drugs_db["Mol_Clean"].apply(Descriptors.NumHDonors)
drugs_db["logp"] = drugs_db["Mol_Clean"].apply(Descriptors.MolLogP)

# %% [markdown]
# ### Merging the dosage form dataset

# %%
# We begin by merging the drugs_db and the actives_route datasets in order to get the route

active_route = pd.read_csv("https://raw.githubusercontent.com/arturcgs/shared_side_projects/main/_Lipinski/data/manually_curated_datasets/active_route_final.csv")

active_route = active_route[["active_stripped", "Route_Unique"]]

# %% [markdown]
# Taking a look at the dataset we are able to see that everything seems ok we have to rename the active_stripped to active to merge both datasets.

# %%
print(f'The active_route dataset has the shape {active_route.shape}')

#Renaming the active_stripped column to active:
active_route.rename(columns = {"active_stripped": "active"}, inplace = True)

active_route.head(4)
# Out:
# The active_route dataset has the shape (856, 2)
#           active  Route_Unique
# 0       abacavir          oral
# 1  abaloparatide  subcutaneous
# 2    abemaciclib          oral
# 3    abiraterone          oral

# %%
drugs_db_with_route = pd.merge(drugs_db, active_route, how = "left", on = "active")

drugs_db_with_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550 entries, 0 to 549
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     550 non-null    int64
#  1   active_ingredient_moiety  550 non-null    object
#  2   nda_bla                   550 non-null    object
#  3   approval_year             550 non-null    int64
#  4   active                    550 non-null    object
#  5   DrugBank ID               550 non-null    object
#  6   Drug Groups               550 non-null    object
#  7   SMILES                    550 non-null    object
#  8   Name                      550 non-null    object
#  9   Drug Type                 550 non-null    object
#  10  ROMol                     550 non-null    object
#  11  Mol_Clean                 550 non-null    object
#  12  mw                        550 non-null    float64
#  13  n_hba                     550 non-null    int64
#  14  n_hbd                     550 non-null    int64
#  15  logp                      550 non-null    float64
#  16  Route_Unique              462 non-null    object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 77.3+ KB

# %%
drugs_db_with_route[["index", "active", "DrugBank ID", "Route_Unique"]].to_csv("drugs_db_with_route.csv")

# %% [markdown]
# After creating the `drugs_db_with_route` we did some manually completion of the remaining route of administration and now we're going to import it and merge the remaining routes.

# %%
# We load the dataset 
drugs_db_with_route_manually = pd.read_csv("https://raw.githubusercontent.com/arturcgs/shared-side-projects/main/_Lipinski/data/manually_curated_datasets/drugs_db_with_route_manually_final.csv")

# Selecting only active and Route_Unique

drugs_db_with_route_manually = drugs_db_with_route_manually[["active", "Route_Unique"]]

# Renaming the Route_Unique to Route only
drugs_db_with_route_manually.rename(columns = {"Route_Unique": "route"}, inplace = True)

drugs_db_with_route_manually.head(10)
# Out:
#          active    route
# 0  troglitazone     oral
# 1     imiquimod  topical
# 2    anagrelide     oral
# 3    nelfinavir     oral
# 4   delavirdine     oral
# 5    tamsulosin     oral
# 6    toremifene     oral
# 7    tazarotene  topical
# 8  cerivastatin     oral
# 9   pramipexole     oral

# %% [markdown]
# ### Merging the datasets route and SMILES and descriptors

# %%
# Merging the datasets (with curated)
drugs_db_route_merged = pd.merge(drugs_db_with_route, drugs_db_with_route_manually, how = "left", on = "active")

# Dropping the Route_Unique columns that has 
drugs_db_route_merged = drugs_db_route_merged.drop(["Route_Unique", "index"], axis = 1)

# Drugs 
drugs_db_route_merged
# Out:
#      active_ingredient_moiety nda_bla  approval_year                active  \
# 0                troglitazone     NDA           1997          troglitazone
# 1                   imiquimod     NDA           1997             imiquimod
# 2    anagrelide hydrochloride     NDA           1997            anagrelide
# 3         nelfinavir mesylate     NDA           1997            nelfinavir
# 4        delavirdine mesylate     NDA           1997           delavirdine
# ..                        ...     ...            ...                   ...
# 545      gadoterate meglumine     NDA           2013  gadoterate meglumine
# 546         dimethyl fumarate     NDA           2013     dimethyl fumarate
# 547               dalbavancin     NDA           2014           dalbavancin
# 548            angiotensin II     NDA           2017        angiotensin II
# 549       tafamidis meglumine     NDA           2019   tafamidis meglumine
#
#     DrugBank ID                           Drug Groups  \
# 0       DB00197  approved; investigational; withdrawn
# 1       DB00724             approved; investigational
# 2       DB00261                              approved
# 3       DB00220                              approved
# 4       DB00705                              approved
# ..          ...                                   ...
# 545     DB09132                              approved
# 546     DB08908             approved; investigational
# 547     DB06219             approved; investigational
# 548     DB11842                            biological
# 549     DB11644             approved; investigational
#
#                                                 SMILES               Name  \
# 0    CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...       Troglitazone
# 1                   CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N          Imiquimod
# 2                      ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl         Anagrelide
# 3    [H][C@@]12CCCC[C@]1([H])CN(C[C@@H](O)[C@H](CSC...         Nelfinavir
# 4    CC(C)NC1=C(N=CC=C1)N1CCN(CC1)C(=O)C1=CC2=C(N1)...        Delavirdine
# ..                                                 ...                ...
# 545  [Gd+3].CNC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO....     Gadoteric acid
# 546                      [H]\C(=C(\[H])C(=O)OC)C(=O)OC  Dimethyl fumarate
# 547  CN[C@H]1C(=O)N[C@@H]2Cc3ccc(Oc4cc5cc(Oc6ccc(cc...        Dalbavancin
# 548  CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O...     Angiotensin II
# 549       OC(=O)C1=CC=C2N=C(OC2=C1)C1=CC(Cl)=CC(Cl)=C1          Tafamidis
#
#              Drug Type                                              ROMol  \
# 0    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 1    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 2    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 3    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 4    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# ..                 ...                                                ...
# 545  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 546  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 547  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 548  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 549  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
#
#                                              Mol_Clean           mw  n_hba  \
# 0    <img data-content="rdkit/molecule" src="data:i...   441.160994      6
# 1    <img data-content="rdkit/molecule" src="data:i...   240.137497      4
# 2    <img data-content="rdkit/molecule" src="data:i...   254.996617      3
# 3    <img data-content="rdkit/molecule" src="data:i...   567.313078      6
# 4    <img data-content="rdkit/molecule" src="data:i...   456.194360      6
# ..                                                 ...          ...    ...
# 545  <img data-content="rdkit/molecule" src="data:i...   599.301387     14
# 546  <img data-content="rdkit/molecule" src="data:i...   144.042259      4
# 547  <img data-content="rdkit/molecule" src="data:i...  1814.608558     29
# 548  <img data-content="rdkit/molecule" src="data:i...  1045.534515     13
# 549  <img data-content="rdkit/molecule" src="data:i...   306.980298      3
#
#      n_hbd     logp        route
# 0        2  4.37426         oral
# 1        1  2.82270      topical
# 2        1  1.92630         oral
# 3        4  4.74762         oral
# 4        3  2.71710         oral
# ..     ...      ...          ...
# 545     10 -5.81190  intravenous
# 546      0 -0.11140         oral
# 547     21  4.16800  intravenous
# 548     13 -1.31470    injection
# 549      1  4.49980         oral
#
# [550 rows x 16 columns]

# %%
drugs_db_route_merged.shape
# Out:
# (550, 16)

# %% [markdown]
# ### Removing the drug groups that has biological

# %%
biological = drugs_db_route_merged["Drug Groups"].str.contains(pat = "biological|polymer")

drugs_db_route_merged = drugs_db_route_merged[~biological].reset_index(drop = True)

# %%
drugs_db_route_merged.shape
# Out:
# (549, 16)

# %% [markdown]
# After removing the drugs that is in the biological groups we are left with 549 structures

# %% [markdown]
# ## 2) Basic data visualization and exploration

# %% [markdown]
# Since the plots are probably going to be published, this is a very good strategy: to set the context with the seaborn function `set_context()`, which automatically does the job of increasing the datapoints and fonts to yield a better visualization

# %%
drugs_db_route_merged.shape
# Out:
# (549, 16)

# %%
sns.set_context("talk")
pd.options.display.max_colwidth = 1000

# %% [markdown]
# The following chunks of code are related to the basic plots of distribution of the lipinski's rule:
#
# - A molecular mass less than 500 daltons
# - No more than 5 hydrogen bond donors (the total number of nitrogen–hydrogen and oxygen–hydrogen bonds)
# - No more than 10 hydrogen bond acceptors (all nitrogen or oxygen atoms)
# - An octanol-water partition coefficient(log P) that does not exceed 5

# %% [markdown]
# Now we're finally able to do the analysis of the data. We have done so far the 1) Cleaning and prep proces 2) Curation of the structres by salt removing and neutralizing the organic molecules. Below we are going to explore each of the calculated descriptors.

# %% [markdown]
# ### 2.1) Molecular Weight distribution

# %% [markdown]
# Plotting the molecular weight distribution:

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom


fig, ax = plt.subplots(figsize = (10,6))

mw_dist = sns.histplot(data = drugs_db_route_merged, x = "mw", 
                       color = "#264653", binwidth = 100).set(title = "FDA approved drugs (1997-2021)", xlabel = "MW (Da)",
                                                            ylabel = "")
ax.axvline(500,color = "#e76f51", linestyle = "--")
ax.set_xlim(0,7500) # setting the xlim
fig.suptitle("Molecular Weight Distribution", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((0, 0),
                        500, 160,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
mw_500 = ((drugs_db_route_merged.mw <=500).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {mw_500:.2%} of the molecules \nobey this rule',
            xy=(0.02, 0.98), xycoords='axes fraction',
            xytext=(0.5, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
#saving plot
fig.savefig("imgs/mw_dist.png", dpi=300)

# %% [markdown]
# We are going to take a look at the strucres with more than 2000 Da. Printing them and their respective <b>SMILES FOR FURTHER ANALYSIS:</b>

# %%
pd.option_context.displaymax_colwidth = 5000 # we have to set the context in order to print all the characters in the smiles columns 

mol_2000_investigate = drugs_db_route_merged[drugs_db_route_merged.mw >= 2000]

print(f'SHAPE: {mol_2000_investigate.shape}')
(mol_2000_investigate[["active","SMILES", "DrugBank ID", "Drug Groups"]])
# Out:
# SHAPE: (7, 16)
#                        active  \
# 99                bivalirudin
# 165                ziconotide
# 168               pramlintide
# 304                mipomersen
# 366                sugammadex
# 400               semaglutide
# 530  ferric gluconate complex
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       SMILES  \
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O
# 165                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168                                                                                                                                                                                                                                                             [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 304  COCCO[C@H]1[C@@H](O)[C@H](COP(O)(=O)S[C@H]2[C@H](COP(O)(=O)S[C@H]3[C@H](COP(O)(=O)S[C@H]4[C@H](COP(O)(=O)S[C@@H]5[C@@H](COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@@H]6[C@@H](COP(O)(=O)S[C@@H]7[C@@H](COP(O)(=O)S[C@@H]8[C@@H](COP(O)(=O)S[C@@H]9[C@@H](COP(O)(=O)S[C@@H]%10[C@@H](CO)O[C@H]([C@@H]%10OCCOC)N%10C=NC%11=C%10N=C(N)NC%11=O)O[C@H]([C@@H]9OCCOC)N9C=C(C)C(N)=NC9=O)O[C@H]([C@@H]8OCCOC)N8C=C(C)C(N)=NC8=O)O[C@H]([C@@H]7OCCOC)N7C=C(C)C(=O)NC7=O)O[C@H]([C@@H]6OCCOC)N6C=C(C)C(N)=NC6=O)N6C=NC7=C6N=CN=C7N)N6C=NC7=C6N=C(N)NC7=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(N)=NC6=O)N6C=C(C)C(=O)NC6=O)N6C=NC7=C6N=C(N)NC7=O)N6C=C(C)C(N)=NC6=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(N)=NC6=O)O[C@H]([C@@H...
# 366                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        O[C@@H]1[C@@H](O)[C@@H]2O[C@H]3O[C@H](CSCCC(O)=O)[C@@H](O[C@H]4O[C@H](CSCCC(O)=O)[C@@H](O[C@H]5O[C@H](CSCCC(O)=O)[C@@H](O[C@H]6O[C@H](CSCCC(O)=O)[C@@H](O[C@H]7O[C@H](CSCCC(O)=O)[C@@H](O[C@H]8O[C@H](CSCCC(O)=O)[C@@H](O[C@H]9O[C@H](CSCCC(O)=O)[C@@H](O[C@H]1O[C@@H]2CSCCC(O)=O)[C@H](O)[C@H]9O)[C@H](O)[C@H]8O)[C@H](O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)[C@H]5O)[C@H](O)[C@H]4O)[C@H](O)[C@H]3O
# 400                                                                                                                                                                                                                                                                                                                                                        CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
# 530                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@H]([C@H]([C@@H]([C@H](C(=O)[O-])O)O)O)O)O.[O-2].[O-2].[O-2].[Na+].[Fe+3].[Fe+3]
#
#     DrugBank ID                Drug Groups
# 99      DB00006  approved; investigational
# 165     DB06283                   approved
# 168     DB01278  approved; investigational
# 304     DB05528  approved; investigational
# 366     DB06206                   approved
# 400     DB13928  approved; investigational
# 530     DB09517                   approved

# %% [markdown]
# ### 2.2) Number of Hydrogen Bond Donors distribution

# %% [markdown]
# Plotting the Hydrogen bond donors distribution:

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom
fig, ax = plt.subplots(figsize = (10,6))

hbd_dist = sns.histplot(data = drugs_db_route_merged, x = "n_hbd", 
                       color = "#264653", binwidth = 1.25).set(title = "FDA approved drugs (1997-2021)", xlabel = "# HBD",
                                                            ylabel = "")
ax.axvline(5,color = "#e76f51", linestyle = "--")
ax.set_xlim(0,70) # setting the xlim
fig.suptitle("Number of Hydrogen Bond Donors", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((0, 0),
                        5, 250,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
n_hbd_5 = ((drugs_db_route_merged.n_hbd <=5).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {n_hbd_5:.2%} of the molecules \nobey this rule',
            xy=(0.02, 0.98), xycoords='axes fraction',
            xytext=(0.5, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
#saving plot
fig.savefig("imgs/hbd.png", dpi=300)

# %%
hbd_investigate = drugs_db_route_merged[drugs_db_route_merged.n_hbd >= 20]

print(f'SHAPE: {hbd_investigate.shape}')
(hbd_investigate[["active","SMILES", "DrugBank ID", "Drug Groups", "n_hbd"]])
# Out:
# SHAPE: (14, 16)
#                        active  \
# 99                bivalirudin
# 142                daptomycin
# 165                ziconotide
# 168               pramlintide
# 242                telavancin
# 304                mipomersen
# 334               oritavancin
# 366                sugammadex
# 376               plecanatide
# 377             etelcalcetide
# 400               semaglutide
# 458             afamelanotide
# 530  ferric gluconate complex
# 547               dalbavancin
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       SMILES  \
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O
# 142                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           CCCCCCCCCC(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@H](CC(N)=O)C(=O)N[C@@H](CC(O)=O)C(=O)N[C@H]1[C@@H](C)OC(=O)[C@H](CC(=O)C2=CC=CC=C2N)NC(=O)[C@@H](NC(=O)[C@@H](CO)NC(=O)CNC(=O)[C@H](CC(O)=O)NC(=O)[C@@H](C)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CCCN)NC(=O)CNC1=O)[C@H](C)CC(O)=O
# 165                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168                                                                                                                                                                                                                                                             [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 242                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 CCCCCCCCCCNCCN[C@@]1(C)C[C@H](O[C@@H]2[C@@H](O)[C@H](O)[C@@H](CO)O[C@H]2OC2=C3OC4=CC=C(C=C4Cl)[C@@H](O)[C@@H](NC(=O)[C@@H](CC(C)C)NC)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H]4C(C=C2OC2=C(Cl)C=C(C=C2)[C@@H](O)[C@@H]2NC(=O)[C@H](NC4=O)C4=CC(=C(O)C=C4)C4=C(O)C(CNCP(O)(O)=O)=C(O)C=C4[C@H](NC2=O)C(O)=O)=C3)O[C@@H](C)[C@H]1O
# 304  COCCO[C@H]1[C@@H](O)[C@H](COP(O)(=O)S[C@H]2[C@H](COP(O)(=O)S[C@H]3[C@H](COP(O)(=O)S[C@H]4[C@H](COP(O)(=O)S[C@@H]5[C@@H](COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@@H]6[C@@H](COP(O)(=O)S[C@@H]7[C@@H](COP(O)(=O)S[C@@H]8[C@@H](COP(O)(=O)S[C@@H]9[C@@H](COP(O)(=O)S[C@@H]%10[C@@H](CO)O[C@H]([C@@H]%10OCCOC)N%10C=NC%11=C%10N=C(N)NC%11=O)O[C@H]([C@@H]9OCCOC)N9C=C(C)C(N)=NC9=O)O[C@H]([C@@H]8OCCOC)N8C=C(C)C(N)=NC8=O)O[C@H]([C@@H]7OCCOC)N7C=C(C)C(=O)NC7=O)O[C@H]([C@@H]6OCCOC)N6C=C(C)C(N)=NC6=O)N6C=NC7=C6N=CN=C7N)N6C=NC7=C6N=C(N)NC7=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(N)=NC6=O)N6C=C(C)C(=O)NC6=O)N6C=NC7=C6N=C(N)NC7=O)N6C=C(C)C(N)=NC6=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(N)=NC6=O)O[C@H]([C@@H...
# 334                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          CN[C@H](CC(C)C)C(=O)N[C@@H]1[C@H](O)C2=CC=C(OC3=C(O[C@@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@H]4O[C@H]4C[C@](C)(NCC5=CC=C(C=C5)C5=CC=C(Cl)C=C5)[C@@H](O)[C@H](C)O4)C4=CC(=C3)[C@@H](NC(=O)[C@H](CC(N)=O)NC1=O)C(=O)N[C@@H]1C3=CC(=C(O)C=C3)C3=C(O)C=C(O)C=C3[C@H](NC(=O)[C@@H](NC1=O)[C@H](O[C@H]1C[C@](C)(N)[C@@H](O)[C@H](C)O1)C1=CC(Cl)=C(O4)C=C1)C(O)=O)C(Cl)=C2
# 366                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        O[C@@H]1[C@@H](O)[C@@H]2O[C@H]3O[C@H](CSCCC(O)=O)[C@@H](O[C@H]4O[C@H](CSCCC(O)=O)[C@@H](O[C@H]5O[C@H](CSCCC(O)=O)[C@@H](O[C@H]6O[C@H](CSCCC(O)=O)[C@@H](O[C@H]7O[C@H](CSCCC(O)=O)[C@@H](O[C@H]8O[C@H](CSCCC(O)=O)[C@@H](O[C@H]9O[C@H](CSCCC(O)=O)[C@@H](O[C@H]1O[C@@H]2CSCCC(O)=O)[C@H](O)[C@H]9O)[C@H](O)[C@H]8O)[C@H](O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)[C@H]5O)[C@H](O)[C@H]4O)[C@H](O)[C@H]3O
# 376                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [H][C@@]12CSSC[C@H](NC(=O)CNC(=O)[C@@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@@H](N)CC(N)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC(C)C)C(=O)N1)NC(=O)[C@H](C)NC(=O)[C@@H](NC(=O)[C@H](CC(N)=O)NC(=O)[C@@H](NC2=O)C(C)C)C(C)C)[C@@H](C)O)C(=O)N[C@@H](CC(C)C)C(O)=O
# 377                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     C[C@@H](NC(=O)[C@@H](CCCNC(N)=N)NC(=O)[C@@H](CCCNC(N)=N)NC(=O)[C@@H](CCCNC(N)=N)NC(=O)[C@@H](C)NC(=O)[C@@H](CSSC[C@H](N)C(O)=O)NC(C)=O)C(=O)N[C@H](CCCNC(N)=N)C(N)=O
# 400                                                                                                                                                                                                                                                                                                                                                        CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
# 458                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           CCCC[C@H](NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(C)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@H](CC1=CC=CC=C1)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC1=CNC2=CC=CC=C12)C(=O)NCC(=O)N[C@@H](CCCCN)C(=O)N1CCC[C@H]1C(=O)N[C@@H](C(C)C)C(N)=O
# 530                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@H]([C@H]([C@@H]([C@H](C(=O)[O-])O)O)O)O)O.[O-2].[O-2].[O-2].[Na+].[Fe+3].[Fe+3]
# 547                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         CN[C@H]1C(=O)N[C@@H]2Cc3ccc(Oc4cc5cc(Oc6ccc(cc6Cl)[C@@H](O)[C@@H]7NC(=O)[C@H](NC(=O)[C@@H]5NC(=O)[C@@H](NC2=O)c8cc(Oc9cc1ccc9O)cc(O)c8Cl)c%10ccc(O)c(c%10)c%11c(O[C@H]%12O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]%12O)cc(O)cc%11[C@@H](NC7=O)C(=O)NCCCN(C)C)c4O[C@@H]%13O[C@@H]([C@@H](O)[C@H](O)[C@H]%13NC(=O)CCCCCCCCC(C)C)C(O)=O)cc3
#
#     DrugBank ID                Drug Groups  n_hbd
# 99      DB00006  approved; investigational     28
# 142     DB00080  approved; investigational     22
# 165     DB06283                   approved     42
# 168     DB01278  approved; investigational     56
# 242     DB06402                   approved     23
# 304     DB05528  approved; investigational     45
# 334     DB04911  approved; investigational     20
# 366     DB06206                   approved     24
# 376     DB13170  approved; investigational     23
# 377     DB12865  approved; investigational     22
# 400     DB13928  approved; investigational     57
# 458     DB04931  approved; investigational     23
# 530     DB09517                   approved     46
# 547     DB06219  approved; investigational     21

# %% [markdown]
# ### 2.3) Number of Hydrogen Bond Acceptors

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom
fig, ax = plt.subplots(figsize = (10,6))

hba_dist = sns.histplot(data = drugs_db_route_merged, x = "n_hba", 
                       color = "#264653", binwidth = 1.25).set(title = "FDA approved drugs (1997-2021)", xlabel = "# HBA",
                                                            ylabel = "")
ax.axvline(10,color = "#e76f51", linestyle = "--")
ax.set_xlim(0,175) # setting the xlim
fig.suptitle("Number of Hydrogen Bond Acceptors", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((0, 0),
                        10, 160,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
n_hba_10 = ((drugs_db_route_merged.n_hba <= 10).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {n_hba_10:.2%} of the molecules \nobey this rule',
            xy=(0.02, 0.98), xycoords='axes fraction',
            xytext=(0.5, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
#saving plot
fig.savefig("imgs/hba_dist.png", dpi=300)

# %%
n_hba_investigate = drugs_db_route_merged[drugs_db_route_merged.n_hba >= 40]

print(f'SHAPE: {n_hba_investigate.shape}')
(n_hba_investigate[["active","SMILES", "DrugBank ID", "Drug Groups", "n_hba"]])
# Out:
# SHAPE: (6, 16)
#                        active  \
# 165                ziconotide
# 168               pramlintide
# 304                mipomersen
# 366                sugammadex
# 400               semaglutide
# 530  ferric gluconate complex
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       SMILES  \
# 165                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168                                                                                                                                                                                                                                                             [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 304  COCCO[C@H]1[C@@H](O)[C@H](COP(O)(=O)S[C@H]2[C@H](COP(O)(=O)S[C@H]3[C@H](COP(O)(=O)S[C@H]4[C@H](COP(O)(=O)S[C@@H]5[C@@H](COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@H]6C[C@@H](O[C@@H]6COP(O)(=O)S[C@@H]6[C@@H](COP(O)(=O)S[C@@H]7[C@@H](COP(O)(=O)S[C@@H]8[C@@H](COP(O)(=O)S[C@@H]9[C@@H](COP(O)(=O)S[C@@H]%10[C@@H](CO)O[C@H]([C@@H]%10OCCOC)N%10C=NC%11=C%10N=C(N)NC%11=O)O[C@H]([C@@H]9OCCOC)N9C=C(C)C(N)=NC9=O)O[C@H]([C@@H]8OCCOC)N8C=C(C)C(N)=NC8=O)O[C@H]([C@@H]7OCCOC)N7C=C(C)C(=O)NC7=O)O[C@H]([C@@H]6OCCOC)N6C=C(C)C(N)=NC6=O)N6C=NC7=C6N=CN=C7N)N6C=NC7=C6N=C(N)NC7=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(N)=NC6=O)N6C=C(C)C(=O)NC6=O)N6C=NC7=C6N=C(N)NC7=O)N6C=C(C)C(N)=NC6=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(=O)NC6=O)N6C=C(C)C(N)=NC6=O)O[C@H]([C@@H...
# 366                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        O[C@@H]1[C@@H](O)[C@@H]2O[C@H]3O[C@H](CSCCC(O)=O)[C@@H](O[C@H]4O[C@H](CSCCC(O)=O)[C@@H](O[C@H]5O[C@H](CSCCC(O)=O)[C@@H](O[C@H]6O[C@H](CSCCC(O)=O)[C@@H](O[C@H]7O[C@H](CSCCC(O)=O)[C@@H](O[C@H]8O[C@H](CSCCC(O)=O)[C@@H](O[C@H]9O[C@H](CSCCC(O)=O)[C@@H](O[C@H]1O[C@@H]2CSCCC(O)=O)[C@H](O)[C@H]9O)[C@H](O)[C@H]8O)[C@H](O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)[C@H]5O)[C@H](O)[C@H]4O)[C@H](O)[C@H]3O
# 400                                                                                                                                                                                                                                                                                                                                                        CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
# 530                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@H]([C@H]([C@@H]([C@H](C(=O)[O-])O)O)O)O)O.[O-2].[O-2].[O-2].[Na+].[Fe+3].[Fe+3]
#
#     DrugBank ID                Drug Groups  n_hba
# 165     DB06283                   approved     45
# 168     DB01278  approved; investigational     59
# 304     DB05528  approved; investigational    180
# 366     DB06206                   approved     48
# 400     DB13928  approved; investigational     56
# 530     DB09517                   approved     61

# %% [markdown]
# ### 2.4) Calculated LogP Distribution

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom
fig, ax = plt.subplots(figsize = (10,6))

logp_dist = sns.histplot(data = drugs_db_route_merged, x = "logp", 
                       color = "#264653", binwidth = 1.25).set(title = "FDA approved drugs (1997-2021)", xlabel = "cLogP",
                                                            ylabel = "")
ax.axvline(5,color = "#e76f51", linestyle = "--")
ax.set_xlim(-35,20) # setting the xlim
fig.suptitle("LogP Distribution", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((-50, 0),
                        55, 140,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
logp_5 = ((drugs_db_route_merged.logp <= 5).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {logp_5:.2%} of the molecules \nobey this rule',
            xy=(0.5, 0.98), xycoords='axes fraction',
            xytext=(0.5, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
#saving plot
fig.savefig("imgs/logp_dist.png", dpi=300)

# %%
logp_investigate = drugs_db_route_merged[drugs_db_route_merged.logp <= -10]

print(f'SHAPE: {logp_investigate.shape}')
(logp_investigate[["active","SMILES", "DrugBank ID", "logp"]])
# Out:
# SHAPE: (6, 16)
#                        active  \
# 116              fondaparinux
# 165                ziconotide
# 168               pramlintide
# 400               semaglutide
# 527                 ardeparin
# 530  ferric gluconate complex
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 116                                                                                                                                                                                                                                                                                                                                                                                                                                                                         CO[C@H]1O[C@H](COS(O)(=O)=O)[C@@H](O[C@@H]2O[C@H]([C@@H](O[C@H]3O[C@H](COS(O)(=O)=O)[C@@H](O[C@@H]4O[C@@H]([C@@H](O[C@H]5O[C@H](COS(O)(=O)=O)[C@@H](O)[C@H](O)[C@H]5NS(O)(=O)=O)[C@H](O)[C@H]4O)C(O)=O)[C@H](OS(O)(=O)=O)[C@H]3NS(O)(=O)=O)[C@H](O)[C@H]2OS(O)(=O)=O)C(O)=O)[C@H](O)[C@H]1NS(O)(=O)=O
# 165                                                                                                                                                                                                                                                                                                                                        [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168  [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 400                                                                                             CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
# 527                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       CC(=O)NC1C(O)OC(CO[S](O)(=O)=O)C(OC2OC(C(OC3OC(CO)C(OC4OC(C(O)C(O)C4O[S](O)(=O)=O)C(O)=O)C(O[S](O)(=O)=O)C3N[S](O)(=O)=O)C(O)C2O[S](O)(=O)=O)C(O)=O)C1O
# 530                                                                                                                                                                                                                                                      C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)O[C@]2([C@H]([C@@H]([C@H](O2)CO)O)O)CO)O)O)O)O.C([C@H]([C@H]([C@@H]([C@H](C(=O)[O-])O)O)O)O)O.[O-2].[O-2].[O-2].[Na+].[Fe+3].[Fe+3]
#
#     DrugBank ID      logp
# 116     DB00569 -13.75010
# 165     DB06283 -16.21286
# 168     DB01278 -23.82513
# 400     DB13928 -11.62786
# 527     DB00407 -10.71190
# 530     DB09517 -30.83250

# %% [markdown]
# ### 2.5) Distribution of the number of followed rules

# %% [markdown]
# We take a first look of the percentage of FDA approved drugs that followed all the Lipinski's rule of five:

# %%
# We create a boolean for obeying all the lipinski rules
lipinski = (drugs_db_route_merged.mw <= 500) & (drugs_db_route_merged.n_hbd <= 5) & (drugs_db_route_merged.n_hba <= 10) & (drugs_db_route_merged.logp <= 5)

# Printing the percentage
print(f"Percentage of FDA approved drugs that followed all of Lipinki's rule of five: "
      f"{drugs_db_route_merged[lipinski].shape[0] / drugs_db_route_merged.shape[0] * 100:.2f}%")
# Out:
# Percentage of FDA approved drugs that followed all of Lipinki's rule of five: 59.93%

# %% [markdown]
# Creating a column for each rule, in order to take a more deep look into each of 4 rules.

# %%
# Creating a column for each rule of the lipinski's rule of five
drugs_db_route_merged["lipinski_mw"] = drugs_db_route_merged.mw <= 500
drugs_db_route_merged["lipinski_hbd"] = drugs_db_route_merged.n_hbd <= 5
drugs_db_route_merged["lipinski_hba"] = drugs_db_route_merged.n_hba <= 10
drugs_db_route_merged["lipinski_logp"] = drugs_db_route_merged.logp <= 5

# How many rules were followed by each structure?
drugs_db_route_merged["n_follow_rules"] = drugs_db_route_merged.iloc[:,-4:].sum(axis = 1)

# %% [markdown]
# Then, we make a plot containing this information:
# ### 2.5.1) Countplot of the number of rules followed by the structures in the period

# %%
# Setting the plot sizes
fig, ax = plt.subplots(figsize = (9,7))

# The plot
lipinski_plot = sns.countplot(data = drugs_db_route_merged, x = "n_follow_rules", color = "#264653").set(title = "FDA approved drugs (1997-2021)", 
                                                                                xlabel = "Number of rules followed", ylabel = "",
                                                                                   ylim = (0,350))
# Title superior to the title plot
fig.suptitle("Distribution of rules followed by the structures", fontsize = 22)


# This part of the code is relative to the size of the respective bar of the countplot
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{}'.format(int(y)), (x.mean(), y), 
            ha='center', va='bottom', fontsize = 18) # set the alignment of the text
#saving plot
fig.savefig("imgs/n_follow_rules_countplot.png", dpi=300)

# %%
# Printing the percentage
print(f"Percentage of FDA approved drugs that followed all of Lipinki's rule of five: "
      f"{drugs_db_route_merged[lipinski].shape[0] / drugs_db_route_merged.shape[0] * 100:.2f}%")
# Out:
# Percentage of FDA approved drugs that followed all of Lipinki's rule of five: 59.93%

# %%
IPythonConsole.drawOptions.useBWAtomPalette()
none_lipinski = list(drugs_db_route_merged[drugs_db_route_merged.n_follow_rules == 0]["SMILES"])

ms = [Chem.MolFromSmiles(x) for x in none_lipinski]

img = Draw.MolsToGridImage(ms, subImgSize = (1550,1550), molsPerRow = 1, returnPNG=False)
img.save("imgs/none_lipinski_molecules.png")

# %%
drugs_db_route_merged[drugs_db_route_merged.n_follow_rules == 0]
# Out:
#     active_ingredient_moiety nda_bla  approval_year         active  \
# 43               rifapentine     NDA           1998    rifapentine
# 269              fidaxomicin     NDA           2011    fidaxomicin
# 456                tenapanor     NDA           2019      tenapanor
# 525            pafolacianine     NDA           2021  pafolacianine
# 540              trypan blue     NDA           2004    trypan blue
#
#     DrugBank ID                Drug Groups  \
# 43      DB01201  approved; investigational
# 269     DB08874                   approved
# 456     DB11761  approved; investigational
# 525     DB15413  approved; investigational
# 540     DB09158                   approved
#
#                                                                                                                                                                                                                         SMILES  \
# 43                                                    CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C2=O)C2=C(C(O)=C3C)C(O)=C(NC(=O)\C(C)=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C)C(\C=N\N1CCN(CC1)C1CCCC1)=C2O
# 269  [H][C@@]1(O[C@@H]2[C@@H](CC)\C=C(C)\[C@@H](O)C\C=C\C=C(CO[C@@H]3O[C@H](C)[C@@H](OC(=O)C4=C(CC)C(Cl)=C(O)C(Cl)=C4O)[C@H](O)[C@@H]3OC)\C(=O)O[C@@H](C\C=C(/C)\C=C2/C)[C@@H](C)O)OC(C)(C)[C@@H](OC(=O)C(C)C)[C@H](O)[C@@H]1O
# 456                                                                         CN1C[C@@H](C2=CC(=CC=C2)S(=O)(=O)NCCOCCOCCNC(=O)NCCCCNC(=O)NCCOCCOCCNS(=O)(=O)C2=CC(=CC=C2)[C@@H]2CN(C)CC3=C2C=C(Cl)C=C3Cl)C2=C(C1)C(Cl)=CC(Cl)=C2
# 525               CC1(C)\C(=C/C=C2\CCCC(\C=C\C3=[N+](CCCCS(O)(=O)=O)C4=C(C=C(C=C4)S([O-])(=O)=O)C3(C)C)=C2OC2=CC=C(C[C@H](NC(=O)C3=CC=C(NCC4=CN=C5N=C(N)NC(=O)C5=N4)C=C3)C(O)=O)C=C2)N(CCCCS(O)(=O)=O)C2=C1C=C(C=C2)S(O)(=O)=O
# 540                                                                                     CC1=CC(=CC=C1\N=N\C1=C(C=C2C=C(C=C(N)C2=C1O)S(O)(=O)=O)S(O)(=O)=O)C1=CC(C)=C(C=C1)\N=N\C1=C(O)C2=C(N)C=C(C=C2C=C1S(O)(=O)=O)S(O)(=O)=O
#
#                       Name          Drug Type  \
# 43             Rifapentine  SmallMoleculeDrug
# 269            Fidaxomicin  SmallMoleculeDrug
# 456              Tenapanor  SmallMoleculeDrug
# 525          Pafolacianine  SmallMoleculeDrug
# 540  Trypan blue free acid  SmallMoleculeDrug
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ROMol  \
# 43   <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 269  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 456  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 525  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 540  <img data-content="rdkit/molecule" src="data:image/png;base64,......
#
#      ...           mw  n_hba  n_hbd     logp        route lipinski_mw  \
# 43   ...   876.452073     15      6  5.64822         oral       False
# 269  ...  1056.425221     18      7  6.23440         oral       False
# 456  ...  1142.309743     12      6  6.15660         oral       False
# 525  ...  1326.361052     18      9  7.22000  intravenous       False
# 540  ...   872.054634     16      8  6.67004   ophthalmic       False
#
#      lipinski_hbd  lipinski_hba  lipinski_logp  n_follow_rules
# 43          False         False          False               0
# 269         False         False          False               0
# 456         False         False          False               0
# 525         False         False          False               0
# 540         False         False          False               0
#
# [5 rows x 21 columns]
