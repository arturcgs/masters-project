# %% [markdown]
# # Exploratory Data Analysis - Lipinksi's rule for the FDA New Chemical Entities (1997-2021)

# %% [markdown]
# After manually curated the dataset (merged from FDA database and DrugBank database) we are going the explore the Lipinski's rules of the ~560 New Chemical Entitities approved by the <b>FDA</b>. About 30 SMILES were manually gathered since none of the two strategies worked (SMILES from name structures or automatically merged with the DrugBank database).
#
# First we need to import the libraries used in this analysis, which is mainly composed of rdkit (to manipulate the structures) and pandas/searborn to do the data analysis.

# %%
from rdkit import Chem, rdBase
from rdkit.Chem import Draw, Descriptors, PandasTools, AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.SaltRemover import SaltRemover, InputFormat

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 1) Loading the and treating the dataset

# %% [markdown]
# Now, we load the database in the csv format. The database was converted to excel and carefully curated: each of the SMILES double checked, most  of the salts removed and was done by GHMS and ACGS.

# %%
# We read the raw data
drugs = pd.read_csv("../data/manually_curated_datasets/fda_small_molecules_smiles.csv")

# Selecting the dataframe without the index that came from the file
drugs = drugs.iloc[:,2:]
drugs.head(3)
# Out:
#    active_ingredient_moiety nda_bla  approval_year        active DrugBank ID  \
# 0              troglitazone     NDA           1997  troglitazone     DB00197
# 1                 imiquimod     NDA           1997     imiquimod     DB00724
# 2  anagrelide hydrochloride     NDA           1997    anagrelide     DB00261
#
#                             Drug Groups  \
# 0  approved; investigational; withdrawn
# 1             approved; investigational
# 2                              approved
#
#                                               SMILES          Name  \
# 0  CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...  Troglitazone
# 1                 CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N     Imiquimod
# 2                    ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl    Anagrelide
#
#            Drug Type
# 0  SmallMoleculeDrug
# 1  SmallMoleculeDrug
# 2  SmallMoleculeDrug

# %%
print(drugs.shape)
drugs[(drugs["SMILES"] == "Not found")]
# Out:
# (560, 9)
#                           active_ingredient_moiety nda_bla  approval_year  \
# 533                      colesevelam hydrochloride     NDA           2000
# 535                              tinzaparin sodium     NDA           2000
# 548                                  kunecatechins     NDA           2006
# 551                         gadofosveset trisodium     NDA           2008
# 556  sulfur hexafluoride lipid-type A microspheres     NDA           2014
# 557                 sodium zirconium cyclosilicate     NDA           2018
#
#                                             active DrugBank ID    Drug Groups  \
# 533                                    colesevelam     DB00930       approved
# 535                                     tinzaparin     DB06822       approved
# 548                                  kunecatechins     DB01266  nutraceutical
# 551                                   gadofosveset     DB06705       contrast
# 556  sulfur hexafluoride lipid-type A microspheres     DB11104       approved
# 557                        zirconium cyclosilicate     DB14048       approved
#
#         SMILES                            Name          Drug Type
# 533  Not found                     Colesevelam  SmallMoleculeDrug
# 535  Not found                      Tinzaparin  SmallMoleculeDrug
# 548  Not found                   Sinecatechins  SmallMoleculeDrug
# 551  Not found          Gadofosveset trisodium  SmallMoleculeDrug
# 556  Not found             Sulfur hexafluoride  SmallMoleculeDrug
# 557  Not found  Sodium zirconium cyclosilicate  SmallMoleculeDrug

# %% [markdown]
# ### 1.1) Initial cleaning and prep

# %% [markdown]
# First, we need to do some cleaning job on the dataset. We need to remove some of the salts  and do some double checking on the stuff. Now we perform the <b>SALT CLEANING</b> and the deionization of the respective base.
#
# We begin by converting the SMILES into the mol format for further analysis

# %%
# correcting the Brilliant Blue G Ophthalmic Solution (it was unreadable)
brilliant_blue_smiles = '[Na+].CCOC1=CC=C(NC2=CC=C(C=C2)C(=C2\C=C/C(/C=C2C)=[N+](/CC)CC2=CC(=CC=C2)S([O-])(=O)=O)\C2=C(C)C=C(C=C2)N(CC)CC2=CC(=CC=C2)S([O-])(=O)=O)C=C1'

drugs.iloc[559,6] = brilliant_blue_smiles
drugs.iloc[559,:]
# Out:
# active_ingredient_moiety                 Brilliant Blue G Ophthalmic Solution
# nda_bla                                                                   NDA
# approval_year                                                            2019
# active                                   Brilliant Blue G Ophthalmic Solution
# DrugBank ID                                                           DB15594
# Drug Groups                                                          approved
# SMILES                      [Na+].CCOC1=CC=C(NC2=CC=C(C=C2)C(=C2\C=C/C(/C=...
# Name                                                         Brilliant blue G
# Drug Type                                                   SmallMoleculeDrug
# Name: 559, dtype: object

# %%
# Removing the "Not Found" SMILES. The SMILES were almost all manually curated in order to gather as many structures as possible
drugs_db = drugs.loc[~(drugs["SMILES"] == "Not found")]
print(drugs_db.shape)
# Adding the ROMol Column, which is the proper format (mol) for further calculations
PandasTools.AddMoleculeColumnToFrame(drugs_db, "SMILES")
# Out:
# (554, 9)
# C:\Users\Gustavo Marques\anaconda3\envs\my-rdkit-env\lib\site-packages\rdkit\Chem\PandasTools.py:449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)

# %% [markdown]
# Then, we make a function to clean the salts from the database. The selected ions were Cl, Br, Na, K and Gd (mainly from contrast structures)

# %%
# defining the salts we want to remove from the database
remover = SaltRemover(defnData="[Cl,Br,Na,K,Gd]")

# Defining the function to neutralize the atoms in organic molecules
def neutralize_atoms(mol):
    pattern = Chem.MolFromSmarts("[+1!h0!$([*]~[-1,-2,-3,-4]),-1!$([*]~[+1,+2,+3,+4])]")
    at_matches = mol.GetSubstructMatches(pattern)
    at_matches_list = [y[0] for y in at_matches]
    if len(at_matches_list) > 0:
        for at_idx in at_matches_list:
            atom = mol.GetAtomWithIdx(at_idx)
            chg = atom.GetFormalCharge()
            hcount = atom.GetTotalNumHs()
            atom.SetFormalCharge(0)
            atom.SetNumExplicitHs(hcount - chg)
            atom.UpdatePropertyCache()
    return mol

# %% [markdown]
# In order to advance into the curation process we need to remove any non-readable or innappropriate smile/structure. We can do this and simutaneously stripping the salts using the function `StripMol()` that uses the `remover.SaltRemover()` function defined earlier.

# %%
mols = [] # creating an empty list

## FUNCTION FOR CHECKING THE NON READABLE:

# Creating a loop to 1) convert from smiles to mol and use the `remover.StripMol() on each structure
for i, smi in enumerate(drugs_db.SMILES):
    try:
        mol = Chem.MolFromSmiles(smi) # converting to a proper format
        mol = remover.StripMol(mol) # stripping the salts
        mols.append(mol) # appending to a list
    except:
        print(smi,i) # printing the exceptions, or the non-readable smiles and the respective index
# Out:
# [H][N]1([H])[C@@H]2CCCC[C@H]2[N]([H])([H])[Pt]11OC(=O)C(=O)O1 124

# %% [markdown]
# We can see that our database has some non-readable smiles that can cause some problems further in the future. We can remove the by doing the `drop()` method allied to `.index[]`.

# %%
drugs_db.shape
# Out:
# (554, 10)

# %%
# dropping the structures found to be non-readable
drugs_db = drugs_db.drop([drugs_db.index[124]]).reset_index(drop=True)

# dropping biotech molecule found manually
drugs_db = drugs_db.drop([drugs_db.index[304]]).reset_index(drop=True)
drugs_db = drugs_db.drop([drugs_db.index[529]]).reset_index(drop=True)
drugs_db = drugs_db.drop([drugs_db.index[526]]).reset_index(drop=True)

# %%
drugs_db.shape
# Out:
# (550, 10)

# %% [markdown]
# We can check again to see if any of the non-readable smiles still lingers on our dataset:

# %%
# Running the same function again (it's better to define a function and just call it again...)
mols = []
for i, smi in enumerate(drugs_db.SMILES):
    try:
        mol = Chem.MolFromSmiles(smi)
        mol = remover.StripMol(neutralize_atoms(mol))
        mols.append(mol)
    except:
        print(smi,i)

# %% [markdown]
# Since there is no structure printed, we can conclude that all the smiles left can be properly converted to mol. We are now able to perform the `remover.StripMol()` and `neutralize_atoms()` at our .mol column,

# %% [markdown]
# ### 1.2) Removing the salts and neutralizing the organic molecules

# %% [markdown]
# Using the `apply` method on the column and performing the functions `StripMol` and `neutralize_atoms`

# %%
# removing the salts
drugs_db["Mol_Clean"] = drugs_db.ROMol.apply(remover.StripMol)

# neutralizing atoms O- goes to OH and so on..
drugs_db["Mol_Clean"] = drugs_db.Mol_Clean.apply(neutralize_atoms)

# %% [markdown]
# ### 1.3) Calculation of the descriptors

# %% [markdown]
# We can see that our method cannot handle to much inorganic information such as the case of talc. Printing the structure we can see:

# %%
drugs_db.Mol_Clean[31]

# %% [markdown]
# Now we calculate the descritptors: Molecular Weight, Number of Hydrogen Acceptors, Number of Hydrogen Donors and LogP that we need to compute the statistcs of the drugs. But first we need to transform the smiles to "mol" format.

# %%
drugs_db["mw"] = drugs_db["Mol_Clean"].apply(Descriptors.ExactMolWt)
drugs_db["n_hba"] = drugs_db["Mol_Clean"].apply(Descriptors.NumHAcceptors)
drugs_db["n_hbd"] = drugs_db["Mol_Clean"].apply(Descriptors.NumHDonors)
drugs_db["logp"] = drugs_db["Mol_Clean"].apply(Descriptors.MolLogP)

# %% [markdown]
# ### Merging the dosage and route form dataset

# %%
# We begin by merging the drugs_db and the actives_route datasets in order to get the route

active_route = pd.read_csv("../data/manually_curated_datasets/active_route_final.csv")

active_route = active_route[["active_stripped", "Route_Unique"]]

# %% [markdown]
# Taking a look at the dataset we are able to see that everything seems ok we have to rename the active_stripped to active to merge both datasets.

# %%
print(f'The active_route dataset has the shape {active_route.shape}')

#Renaming the active_stripped column to active:
active_route.rename(columns = {"active_stripped": "active"}, inplace = True)

active_route.head(4)
# Out:
# The active_route dataset has the shape (856, 2)
#           active  Route_Unique
# 0       abacavir          oral
# 1  abaloparatide  subcutaneous
# 2    abemaciclib          oral
# 3    abiraterone          oral

# %%
drugs_db_with_route = pd.merge(drugs_db, active_route, how = "left", on = "active")

drugs_db_with_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550 entries, 0 to 549
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   active_ingredient_moiety  550 non-null    object
#  1   nda_bla                   550 non-null    object
#  2   approval_year             550 non-null    int64
#  3   active                    550 non-null    object
#  4   DrugBank ID               550 non-null    object
#  5   Drug Groups               550 non-null    object
#  6   SMILES                    550 non-null    object
#  7   Name                      546 non-null    object
#  8   Drug Type                 546 non-null    object
#  9   ROMol                     550 non-null    object
#  10  Mol_Clean                 550 non-null    object
#  11  mw                        550 non-null    float64
#  12  n_hba                     550 non-null    int64
#  13  n_hbd                     550 non-null    int64
#  14  logp                      550 non-null    float64
#  15  Route_Unique              462 non-null    object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 73.0+ KB

# %%
drugs_db_with_route[["active", "DrugBank ID", "Route_Unique"]].to_csv("drugs_db_with_route.csv", index=False)

# %% [markdown]
# After creating the `drugs_db_with_route` we did some manually completion of the remaining route of administration and now we're going to import it and merge the remaining routes.

# %%
# We load the dataset 
drugs_db_with_route_manually = pd.read_csv("../data/manually_curated_datasets/drugs_db_with_route_manually_final.csv")

# Selecting only active and Route_Unique

drugs_db_with_route_manually = drugs_db_with_route_manually[["active", "Route_Unique"]]

# Renaming the Route_Unique to Route only
drugs_db_with_route_manually.rename(columns = {"Route_Unique": "route"}, inplace = True)

print(drugs_db_with_route_manually.shape)
drugs_db_with_route_manually.head(10)
# Out:
# (551, 2)
#          active    route
# 0  troglitazone     oral
# 1     imiquimod  topical
# 2    anagrelide     oral
# 3    nelfinavir     oral
# 4   delavirdine     oral
# 5    tamsulosin     oral
# 6    toremifene     oral
# 7    tazarotene  topical
# 8  cerivastatin     oral
# 9   pramipexole     oral

# %% [markdown]
# ### Merging the datasets route and SMILES and descriptors

# %%
# Merging the datasets (with curated)
drugs_db_route_merged = pd.merge(drugs_db_with_route, drugs_db_with_route_manually, how = "left", on = "active")

# Dropping the Route_Unique columns that has 
drugs_db_route_merged = drugs_db_route_merged.drop(["Route_Unique"], axis = 1)

# Drugs 
drugs_db_route_merged
# Out:
#                  active_ingredient_moiety nda_bla  approval_year  \
# 0                            troglitazone     NDA           1997
# 1                               imiquimod     NDA           1997
# 2                anagrelide hydrochloride     NDA           1997
# 3                     nelfinavir mesylate     NDA           1997
# 4                    delavirdine mesylate     NDA           1997
# ..                                    ...     ...            ...
# 545                  gadoterate meglumine     NDA           2013
# 546                     dimethyl fumarate     NDA           2013
# 547                           dalbavancin     NDA           2014
# 548                   tafamidis meglumine     NDA           2019
# 549  Brilliant Blue G Ophthalmic Solution     NDA           2019
#
#                                    active DrugBank ID  \
# 0                            troglitazone     DB00197
# 1                               imiquimod     DB00724
# 2                              anagrelide     DB00261
# 3                              nelfinavir     DB00220
# 4                             delavirdine     DB00705
# ..                                    ...         ...
# 545                  gadoterate meglumine     DB09132
# 546                     dimethyl fumarate     DB08908
# 547                           dalbavancin     DB06219
# 548                   tafamidis meglumine     DB11644
# 549  Brilliant Blue G Ophthalmic Solution     DB15594
#
#                               Drug Groups  \
# 0    approved; investigational; withdrawn
# 1               approved; investigational
# 2                                approved
# 3                                approved
# 4                                approved
# ..                                    ...
# 545                              approved
# 546             approved; investigational
# 547             approved; investigational
# 548             approved; investigational
# 549                              approved
#
#                                                 SMILES               Name  \
# 0    CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...       Troglitazone
# 1                   CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N          Imiquimod
# 2                      ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl         Anagrelide
# 3    [H][C@@]12CCCC[C@]1([H])CN(C[C@@H](O)[C@H](CSC...         Nelfinavir
# 4    CC(C)NC1=C(N=CC=C1)N1CCN(CC1)C(=O)C1=CC2=C(N1)...        Delavirdine
# ..                                                 ...                ...
# 545  [Gd+3].CNC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO....     Gadoteric acid
# 546                      [H]\C(=C(\[H])C(=O)OC)C(=O)OC  Dimethyl fumarate
# 547  CN[C@H]1C(=O)N[C@@H]2Cc3ccc(Oc4cc5cc(Oc6ccc(cc...        Dalbavancin
# 548       OC(=O)C1=CC=C2N=C(OC2=C1)C1=CC(Cl)=CC(Cl)=C1          Tafamidis
# 549  [Na+].CCOC1=CC=C(NC2=CC=C(C=C2)C(=C2\C=C/C(/C=...   Brilliant blue G
#
#              Drug Type                                              ROMol  \
# 0    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 1    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 2    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 3    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 4    SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# ..                 ...                                                ...
# 545  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 546  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 547  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 548  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
# 549  SmallMoleculeDrug  <img data-content="rdkit/molecule" src="data:i...
#
#                                              Mol_Clean           mw  n_hba  \
# 0    <img data-content="rdkit/molecule" src="data:i...   441.160994      6
# 1    <img data-content="rdkit/molecule" src="data:i...   240.137497      4
# 2    <img data-content="rdkit/molecule" src="data:i...   254.996617      3
# 3    <img data-content="rdkit/molecule" src="data:i...   567.313078      6
# 4    <img data-content="rdkit/molecule" src="data:i...   456.194360      6
# ..                                                 ...          ...    ...
# 545  <img data-content="rdkit/molecule" src="data:i...   599.301387     14
# 546  <img data-content="rdkit/molecule" src="data:i...   144.042259      4
# 547  <img data-content="rdkit/molecule" src="data:i...  1814.608558     29
# 548  <img data-content="rdkit/molecule" src="data:i...   306.980298      3
# 549  <img data-content="rdkit/molecule" src="data:i...   832.308469      7
#
#      n_hbd     logp        route
# 0        2  4.37426         oral
# 1        1  2.82270      topical
# 2        1  1.92630         oral
# 3        4  4.74762         oral
# 4        3  2.71710         oral
# ..     ...      ...          ...
# 545     10 -5.81190  intravenous
# 546      0 -0.11140         oral
# 547     21  4.16800  intravenous
# 548      1  4.49980         oral
# 549      3  9.64882   ophthalmic
#
# [550 rows x 16 columns]

# %%
drugs_db_route_merged.shape
# Out:
# (550, 16)

# %%
drugs_db_route_merged[drugs_db_route_merged["route"].isna()]
# Out:
#         active_ingredient_moiety nda_bla  approval_year  \
# 527                 eptifibatide     NDA           1998
# 530        unoprostone isopropyl     NDA           2000
# 532           cefditoren pivoxil     NDA           2001
# 536  pentetate calcium trisodium     NDA           2004
#
#                     active   DrugBank ID                Drug Groups  \
# 527           eptifibatide       DB00063  approved; investigational
# 530  unoprostone isopropyl  DBSALT001760                   approved
# 532     cefditoren pivoxil  DBSALT001811                   approved
# 536              pentetate       DB06806                   approved
#
#                                                 SMILES Name Drug Type  \
# 527  NC(N)=NCCCCC1NC(=O)CCSSCC(NC(=O)C2CCCN2C(=O)C(...  NaN       NaN
# 530  CCCCCCCC(=O)CC[C@H]1[C@@H](C[C@@H]([C@@H]1C/C=...  NaN       NaN
# 532  [H][C@]12SCC(\C=C/C3=C(C)N=CS3)=C(N1C(=O)[C@H]...  NaN       NaN
# 536  [O-]C(=O)CN(CCN(CC([O-])=O)CC([O-])=O)CCN(CC([...  NaN       NaN
#
#                                                  ROMol  \
# 527  <img data-content="rdkit/molecule" src="data:i...
# 530  <img data-content="rdkit/molecule" src="data:i...
# 532  <img data-content="rdkit/molecule" src="data:i...
# 536  <img data-content="rdkit/molecule" src="data:i...
#
#                                              Mol_Clean          mw  n_hba  \
# 527  <img data-content="rdkit/molecule" src="data:i...  831.315614     11
# 530  <img data-content="rdkit/molecule" src="data:i...  424.318875      5
# 532  <img data-content="rdkit/molecule" src="data:i...  620.118160     14
# 536  <img data-content="rdkit/molecule" src="data:i...  393.138344      8
#
#      n_hbd     logp route
# 527     10 -2.05440   NaN
# 530      2  5.12230   NaN
# 532      2  2.29812   NaN
# 536      5 -2.68460   NaN

# %% [markdown]
# We complete manually the not-found routes as below:

# %%
drugs_db_route_merged.loc[529,"route"] = "intravenous"
drugs_db_route_merged.loc[533, "route"] = "ophthalmic"
drugs_db_route_merged.loc[535,"route"] = "oral"
drugs_db_route_merged.loc[539,"route"] = "intravenous"

# %% [markdown]
# ### Removing the drug groups that has biological

# %%
biological = drugs_db_route_merged["Drug Groups"].str.contains(pat = "biological|polymer")
drugs_db_route_merged = drugs_db_route_merged[~biological].reset_index(drop = True)

# %%
drugs_db_route_merged.shape
# Out:
# (550, 16)

# %% [markdown]
# After removing the drugs that is in the biological groups we are left with 550 structures

# %% [markdown]
# ## 2) Basic data visualization and exploration

# %% [markdown]
# Since the plots are probably going to be published, this is a very good strategy: to set the context with the seaborn function `set_context()`, which automatically does the job of increasing the datapoints and fonts to yield a better visualization

# %%
drugs_db_route_merged.shape
# Out:
# (550, 16)

# %%
sns.set_context("talk")
pd.options.display.max_colwidth = 1000

# %% [markdown]
# The following chunks of code are related to the basic plots of distribution of the lipinski's rule:
#
# - A molecular mass less than 500 daltons
# - No more than 5 hydrogen bond donors (the total number of nitrogen–hydrogen and oxygen–hydrogen bonds)
# - No more than 10 hydrogen bond acceptors (all nitrogen or oxygen atoms)
# - An octanol-water partition coefficient(log P) that does not exceed 5

# %% [markdown]
# Now we're finally able to do the analysis of the data. We have done so far the 1) Cleaning and prep proces 2) Curation of the structres by salt removing and neutralizing the organic molecules. Below we are going to explore each of the calculated descriptors.

# %% [markdown]
# ### 2.1) Molecular Weight distribution

# %% [markdown]
# Plotting the molecular weight distribution:

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom


fig, ax = plt.subplots(figsize = (10,6))

mw_dist = sns.histplot(data = drugs_db_route_merged, x = "mw", 
                       color = "#264653", binwidth = 100).set(title = "FDA approved drugs (1997-2021)", 
                                                              xlabel = "MW (Da)", ylabel = "")
ax.axvline(500,color = "#e76f51", linestyle = "--")
ax.set_xlim(0,3000) # setting the xlim
fig.suptitle("Molecular Weight Distribution", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((0, 0),
                        500, 160,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
mw_500 = ((drugs_db_route_merged.mw <=500).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {mw_500:.2%} of the molecules \nobey this rule',
            xy=(0.09, 0.98), xycoords='axes fraction',
            xytext=(0.55, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
# saving plot
fig.savefig("../imgs/mw_dist.png", dpi=300)

# %% [markdown]
# We are going to take a look at the strucres with more than 2000 Da. Printing them and their respective <b>SMILES FOR FURTHER ANALYSIS:</b>

# %%
pd.option_context.displaymax_colwidth = 5000 # we have to set the context in order to print all the characters in the smiles columns 

mol_2000_investigate = drugs_db_route_merged[drugs_db_route_merged.mw >= 2000]

print(f'SHAPE: {mol_2000_investigate.shape}')
(mol_2000_investigate[["active","SMILES", "DrugBank ID", "Drug Groups"]])
# Out:
# SHAPE: (5, 16)
#           active  \
# 99   bivalirudin
# 165   ziconotide
# 168  pramlintide
# 365   sugammadex
# 399  semaglutide
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 99                                                                                                                                                                                                                                                                                                                                                                                                          CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O
# 165                                                                                                                                                                                                                                                                                                                                        [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168  [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 365                                                                                                                                                                                                                                                                                                                                                                             O[C@@H]1[C@@H](O)[C@@H]2O[C@H]3O[C@H](CSCCC(O)=O)[C@@H](O[C@H]4O[C@H](CSCCC(O)=O)[C@@H](O[C@H]5O[C@H](CSCCC(O)=O)[C@@H](O[C@H]6O[C@H](CSCCC(O)=O)[C@@H](O[C@H]7O[C@H](CSCCC(O)=O)[C@@H](O[C@H]8O[C@H](CSCCC(O)=O)[C@@H](O[C@H]9O[C@H](CSCCC(O)=O)[C@@H](O[C@H]1O[C@@H]2CSCCC(O)=O)[C@H](O)[C@H]9O)[C@H](O)[C@H]8O)[C@H](O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)[C@H]5O)[C@H](O)[C@H]4O)[C@H](O)[C@H]3O
# 399                                                                                             CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
#
#     DrugBank ID                Drug Groups
# 99      DB00006  approved; investigational
# 165     DB06283                   approved
# 168     DB01278  approved; investigational
# 365     DB06206                   approved
# 399     DB13928  approved; investigational

# %% [markdown]
# ### 2.2) Number of Hydrogen Bond Donors distribution

# %% [markdown]
# Plotting the Hydrogen bond donors distribution:

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom
fig, ax = plt.subplots(figsize = (10,6))

hbd_dist = sns.histplot(data = drugs_db_route_merged, x = "n_hbd", 
                       color = "#264653", binwidth = 1.25).set(title = "FDA approved drugs (1997-2021)", xlabel = "# HBD",
                                                            ylabel = "")
ax.axvline(5,color = "#e76f51", linestyle = "--")
ax.set_xlim(0,25) # setting the xlim
fig.suptitle("Number of Hydrogen Bond Donors", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((0, 0),
                        5, 250,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
n_hbd_5 = ((drugs_db_route_merged.n_hbd <=5).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {n_hbd_5:.2%} of the molecules \nobey this rule',
            xy=(0.09, 0.95), xycoords='axes fraction',
            xytext=(0.56, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
# saving plot
fig.savefig("../imgs/hbd.png", dpi=300)

# %%
hbd_investigate = drugs_db_route_merged[drugs_db_route_merged.n_hbd >= 25]

print(f'SHAPE: {hbd_investigate.shape}')
(hbd_investigate[["active","SMILES", "DrugBank ID", "Drug Groups", "n_hbd"]])
# Out:
# SHAPE: (4, 16)
#           active  \
# 99   bivalirudin
# 165   ziconotide
# 168  pramlintide
# 399  semaglutide
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 99                                                                                                                                                                                                                                                                                                                                                                                                          CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O
# 165                                                                                                                                                                                                                                                                                                                                        [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168  [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 399                                                                                             CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
#
#     DrugBank ID                Drug Groups  n_hbd
# 99      DB00006  approved; investigational     28
# 165     DB06283                   approved     42
# 168     DB01278  approved; investigational     56
# 399     DB13928  approved; investigational     57

# %% [markdown]
# ### 2.3) Number of Hydrogen Bond Acceptors

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom
fig, ax = plt.subplots(figsize = (10,6))

hba_dist = sns.histplot(data = drugs_db_route_merged, x = "n_hba", 
                       color = "#264653", binwidth = 1.25).set(title = "FDA approved drugs (1997-2021)", xlabel = "# HBA",
                                                            ylabel = "")
ax.axvline(10,color = "#e76f51", linestyle = "--")
ax.set_xlim(0,40) # setting the xlim
fig.suptitle("Number of Hydrogen Bond Acceptors", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((0, 0),
                        10, 160,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
n_hba_10 = ((drugs_db_route_merged.n_hba <= 10).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {n_hba_10:.2%} of the molecules \nobey this rule',
            xy=(0.12, 0.98), xycoords='axes fraction',
            xytext=(0.65, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
#saving plot
fig.savefig("../imgs/hba_dist.png", dpi=300)

# %%
n_hba_investigate = drugs_db_route_merged[drugs_db_route_merged.n_hba >= 40]

print(f'SHAPE: {n_hba_investigate.shape}')
(n_hba_investigate[["active","SMILES", "DrugBank ID", "Drug Groups", "n_hba", "route"]])
# Out:
# SHAPE: (4, 16)
#           active  \
# 165   ziconotide
# 168  pramlintide
# 365   sugammadex
# 399  semaglutide
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 165                                                                                                                                                                                                                                                                                                                                        [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168  [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 365                                                                                                                                                                                                                                                                                                                                                                             O[C@@H]1[C@@H](O)[C@@H]2O[C@H]3O[C@H](CSCCC(O)=O)[C@@H](O[C@H]4O[C@H](CSCCC(O)=O)[C@@H](O[C@H]5O[C@H](CSCCC(O)=O)[C@@H](O[C@H]6O[C@H](CSCCC(O)=O)[C@@H](O[C@H]7O[C@H](CSCCC(O)=O)[C@@H](O[C@H]8O[C@H](CSCCC(O)=O)[C@@H](O[C@H]9O[C@H](CSCCC(O)=O)[C@@H](O[C@H]1O[C@@H]2CSCCC(O)=O)[C@H](O)[C@H]9O)[C@H](O)[C@H]8O)[C@H](O)[C@H]7O)[C@H](O)[C@H]6O)[C@H](O)[C@H]5O)[C@H](O)[C@H]4O)[C@H](O)[C@H]3O
# 399                                                                                             CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
#
#     DrugBank ID                Drug Groups  n_hba              route
# 165     DB06283                   approved     45        intrathecal
# 168     DB01278  approved; investigational     59       subcutaneous
# 365     DB06206                   approved     48        intravenous
# 399     DB13928  approved; investigational     56  subcutaneous oral

# %% [markdown]
# ### 2.4) Calculated LogP Distribution

# %%
from matplotlib.patches import Rectangle
from matplotlib.text import OffsetFrom
fig, ax = plt.subplots(figsize = (10,6))

logp_dist = sns.histplot(data = drugs_db_route_merged, x = "logp", 
                       color = "#264653", binwidth = 1.25).set(title = "FDA approved drugs (1997-2021)", xlabel = "cLogP",
                                                            ylabel = "")
ax.axvline(5,color = "#e76f51", linestyle = "--")
ax.set_xlim(-20,20) # setting the xlim
fig.suptitle("LogP Distribution", fontsize = 22)

# adding a shaded region
ax.add_patch(Rectangle((-50, 0),
                        55, 150,
                        fc ='g', 
                        ec ='none',
                        lw = 10, alpha = .1))

# annotating the information about how % obey the lipinski's rules
logp_5 = ((drugs_db_route_merged.logp <= 5).sum())/drugs_db_route_merged.shape[0]

ax.annotate(f' {logp_5:.2%} of the\nmolecules obey\nthis rule',
            xy=(0.50, 0.98), xycoords='axes fraction',
            xytext=(0.92, 0.75), textcoords='axes fraction',
            arrowprops={"arrowstyle":"<-", "color":"g", "lw":"1", "connectionstyle":"arc3,rad=0.3"},
            horizontalalignment='right',
            verticalalignment='top', fontsize=14)
#saving plot
fig.savefig("../imgs/logp_dist.png", dpi=300)

# %%
logp_investigate = drugs_db_route_merged[drugs_db_route_merged.logp <= -10]

print(f'SHAPE: {logp_investigate.shape}')
(logp_investigate[["active","SMILES", "DrugBank ID", "logp"]])
# Out:
# SHAPE: (4, 16)
#            active  \
# 116  fondaparinux
# 165    ziconotide
# 168   pramlintide
# 399   semaglutide
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 116                                                                                                                                                                                                                                                                                                                                                                                                                                                                         CO[C@H]1O[C@H](COS(O)(=O)=O)[C@@H](O[C@@H]2O[C@H]([C@@H](O[C@H]3O[C@H](COS(O)(=O)=O)[C@@H](O[C@@H]4O[C@@H]([C@@H](O[C@H]5O[C@H](COS(O)(=O)=O)[C@@H](O)[C@H](O)[C@H]5NS(O)(=O)=O)[C@H](O)[C@H]4O)C(O)=O)[C@H](OS(O)(=O)=O)[C@H]3NS(O)(=O)=O)[C@H](O)[C@H]2OS(O)(=O)=O)C(O)=O)[C@H](O)[C@H]1NS(O)(=O)=O
# 165                                                                                                                                                                                                                                                                                                                                        [H][C@]12CSSC[C@]3([H])NC(=O)[C@H](CCCCN)NC(=O)[C@H](C)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CCCCN)NC(=O)[C@@H](N)CSSC[C@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCCCN)NC(=O)CNC(=O)[C@H](CO)NC(=O)[C@H](CCCNC(N)=N)NC1=O)C(N)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CCSC)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CO)NC3=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N[C@@H](CO)C(=O)N2
# 168  [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 399                                                                                             CC[C@H](C)[C@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCCCNC(=O)COCCOCCNC(=O)COCCOCCNC(=O)CC[C@@H](NC(=O)CCCCCCCCCCCCCCCCC(O)=O)C(O)=O)NC(=O)[C@H](C)NC(=O)[C@H](C)NC(=O)[C@H](CCC(N)=O)NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC(O)=O)NC(=O)[C@H](CO)NC(=O)[C@@H](NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@@H](NC(=O)CNC(=O)[C@H](CCC(O)=O)NC(=O)C(C)(C)NC(=O)[C@@H](N)CC1=CN=CN1)[C@@H](C)O)[C@@H](C)O)C(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(=O)N[C@@H](CCCNC(N)=N)C(=O)NCC(O)=O
#
#     DrugBank ID      logp
# 116     DB00569 -13.75010
# 165     DB06283 -16.21286
# 168     DB01278 -23.82513
# 399     DB13928 -11.62786

# %%
#create graph
joint_plot = sns.jointplot(y = 'logp', x = "mw", data = drugs_db_route_merged, height = 12, alpha=0.5)

# creating lines
joint_plot.ax_joint.axvline(x=500, linestyle='--', color = 'gray', alpha=0.4)
joint_plot.ax_joint.axhline(y=5, linestyle='--', color = 'gray', alpha=0.4)


# adding a shaded region
joint_plot.ax_joint.add_patch(Rectangle((-1000, -40),
                        1500, 45,
                        fc ='gray', 
                        ec ='none',
                        lw = 10, alpha = .1))

# changing x and y label
joint_plot.ax_joint.set_xlabel('Molecular Weight')
joint_plot.ax_joint.set_ylabel('LogP')

#saving plot
joint_plot.savefig("../imgs/logp_mw_jointplot.png", dpi=300)

plt.show()

# %% [markdown]
# ### 2.5) Distribution of the number of followed rules

# %% [markdown]
# We take a first look of the percentage of FDA approved drugs that followed all the Lipinski's rule of five:

# %%
# We create a boolean for obeying all the lipinski rules
lipinski = (drugs_db_route_merged.mw <= 500) & (drugs_db_route_merged.n_hbd <= 5) & (drugs_db_route_merged.n_hba <= 10) & (drugs_db_route_merged.logp <= 5)

# Printing the percentage
print(f"Percentage of FDA approved drugs that followed all of Lipinki's rule of five: "
      f"{drugs_db_route_merged[lipinski].shape[0] / drugs_db_route_merged.shape[0] * 100:.2f}%")
# Out:
# Percentage of FDA approved drugs that followed all of Lipinki's rule of five: 60.00%

# %% [markdown]
# Creating a column for each rule, in order to take a more deep look into each of 4 rules.

# %%
# Creating a column for each rule of the lipinski's rule of five
drugs_db_route_merged["lipinski_mw"] = drugs_db_route_merged.mw <= 500
drugs_db_route_merged["lipinski_hbd"] = drugs_db_route_merged.n_hbd <= 5
drugs_db_route_merged["lipinski_hba"] = drugs_db_route_merged.n_hba <= 10
drugs_db_route_merged["lipinski_logp"] = drugs_db_route_merged.logp <= 5

# How many rules were followed by each structure?
drugs_db_route_merged["n_follow_rules"] = drugs_db_route_merged.iloc[:,-4:].sum(axis = 1)

# %% [markdown]
# Then, we make a plot containing this information:
# ### 2.5.1) Countplot of the number of rules followed by the structures in the period

# %%
# Setting the plot sizes
sns.set_context("talk", font_scale = 1.6)
fig, ax = plt.subplots(figsize = (15,10))

# The plot
lipinski_plot = sns.countplot(data = drugs_db_route_merged, x = "n_follow_rules", color = "#264653").set(title = "FDA approved drugs (1997-2021)", 
                                                                                xlabel = "Number of rules followed", ylabel = "",
                                                                                   ylim = (0,350))
# Title superior to the title plot
fig.suptitle("Distribution of rules followed by the structures", fontsize = 32)

# This part of the code is relative to the size of the respective bar of the countplot
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{}'.format(int(y)), (x.mean(), y), 
            ha='center', va='bottom', fontsize = 29) # set the alignment of the text
    
#saving plot
fig.savefig("../imgs/n_follow_rules_countplot.png", dpi=300)

# %%
# Printing the percentage
print(f"Percentage of FDA approved drugs that followed all of Lipinki's rule of five: "
      f"{drugs_db_route_merged[lipinski].shape[0] / drugs_db_route_merged.shape[0] * 100:.2f}%")
# Out:
# Percentage of FDA approved drugs that followed all of Lipinki's rule of five: 60.00%

# %%
drugs_db_route_merged.shape
# Out:
# (550, 21)

# %% [markdown]
# ### Saving the structures that do not follow any of the rules

# %%
IPythonConsole.drawOptions.useBWAtomPalette()
none_lipinski = list(drugs_db_route_merged[drugs_db_route_merged.n_follow_rules == 0]["SMILES"])

ms = [Chem.MolFromSmiles(x) for x in none_lipinski]

img = Draw.MolsToGridImage(ms, subImgSize = (1250,770), molsPerRow = 2, returnPNG=False, 
                           legends = list(drugs_db_route_merged[drugs_db_route_merged.n_follow_rules == 0]["active"]))
img.save("../imgs/none_lipinski_molecules.png")

# %%
drugs_db_route_merged[drugs_db_route_merged.n_follow_rules == 0]
# Out:
#     active_ingredient_moiety nda_bla  approval_year         active  \
# 43               rifapentine     NDA           1998    rifapentine
# 269              fidaxomicin     NDA           2011    fidaxomicin
# 455                tenapanor     NDA           2019      tenapanor
# 524            pafolacianine     NDA           2021  pafolacianine
# 540              trypan blue     NDA           2004    trypan blue
#
#     DrugBank ID                Drug Groups  \
# 43      DB01201  approved; investigational
# 269     DB08874                   approved
# 455     DB11761  approved; investigational
# 524     DB15413  approved; investigational
# 540     DB09158                   approved
#
#                                                                                                                                                                                                                         SMILES  \
# 43                                                    CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C2=O)C2=C(C(O)=C3C)C(O)=C(NC(=O)\C(C)=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C)C(\C=N\N1CCN(CC1)C1CCCC1)=C2O
# 269  [H][C@@]1(O[C@@H]2[C@@H](CC)\C=C(C)\[C@@H](O)C\C=C\C=C(CO[C@@H]3O[C@H](C)[C@@H](OC(=O)C4=C(CC)C(Cl)=C(O)C(Cl)=C4O)[C@H](O)[C@@H]3OC)\C(=O)O[C@@H](C\C=C(/C)\C=C2/C)[C@@H](C)O)OC(C)(C)[C@@H](OC(=O)C(C)C)[C@H](O)[C@@H]1O
# 455                                                                         CN1C[C@@H](C2=CC(=CC=C2)S(=O)(=O)NCCOCCOCCNC(=O)NCCCCNC(=O)NCCOCCOCCNS(=O)(=O)C2=CC(=CC=C2)[C@@H]2CN(C)CC3=C2C=C(Cl)C=C3Cl)C2=C(C1)C(Cl)=CC(Cl)=C2
# 524               CC1(C)\C(=C/C=C2\CCCC(\C=C\C3=[N+](CCCCS(O)(=O)=O)C4=C(C=C(C=C4)S([O-])(=O)=O)C3(C)C)=C2OC2=CC=C(C[C@H](NC(=O)C3=CC=C(NCC4=CN=C5N=C(N)NC(=O)C5=N4)C=C3)C(O)=O)C=C2)N(CCCCS(O)(=O)=O)C2=C1C=C(C=C2)S(O)(=O)=O
# 540                                                                                     CC1=CC(=CC=C1\N=N\C1=C(C=C2C=C(C=C(N)C2=C1O)S(O)(=O)=O)S(O)(=O)=O)C1=CC(C)=C(C=C1)\N=N\C1=C(O)C2=C(N)C=C(C=C2C=C1S(O)(=O)=O)S(O)(=O)=O
#
#                       Name          Drug Type  \
# 43             Rifapentine  SmallMoleculeDrug
# 269            Fidaxomicin  SmallMoleculeDrug
# 455              Tenapanor  SmallMoleculeDrug
# 524          Pafolacianine  SmallMoleculeDrug
# 540  Trypan blue free acid  SmallMoleculeDrug
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ROMol  \
# 43   <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 269  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 455  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 524  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 540  <img data-content="rdkit/molecule" src="data:image/png;base64,......
#
#      ...           mw  n_hba  n_hbd     logp        route lipinski_mw  \
# 43   ...   876.452073     15      6  5.64822         oral       False
# 269  ...  1056.425221     18      7  6.23440         oral       False
# 455  ...  1142.309743     12      6  6.15660         oral       False
# 524  ...  1326.361052     18      9  7.22000  intravenous       False
# 540  ...   872.054634     16      8  6.67004   ophthalmic       False
#
#      lipinski_hbd  lipinski_hba  lipinski_logp  n_follow_rules
# 43          False         False          False               0
# 269         False         False          False               0
# 455         False         False          False               0
# 524         False         False          False               0
# 540         False         False          False               0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2.5.2) Countplot of the number of rules followed by the structures per year

# %%
# Setting the plot sizes
fig, ax = plt.subplots(figsize = (16,20))

# The plot
lipinski_plot = sns.countplot(data = drugs_db_route_merged, y = "approval_year", hue = 'n_follow_rules')

lipinski_plot.set_title("FDA approved drugs (1997-2021)", pad = 15, fontsize = 30)
lipinski_plot.set_xlabel("Number of FDA approved drugs", size = 30)
lipinski_plot.set_ylabel("", size = 10)
#Increasing y-tick label size
lipinski_plot.tick_params(labelsize = 26)
# Title superior to the title plot
fig.suptitle("Distribution of rules followed by the structures\nseparated by year", fontsize = 45)

# Legend title
ax.legend(title='Number of rules\n      followed')

#saving plot
fig.savefig("../imgs/n_follow_rules_countplot_per_year.png", dpi=300)

# %% [markdown]
# ### 2.6) Analysing only the Drugs with oral route of admnistration
#
# Lipinski's rule of 5 was made with the thought of filtering molecules for possible oral admnistration.

# %%
# separating the db

drugs_oral = drugs_db_route_merged[drugs_db_route_merged.route == 'oral']
print(drugs_oral.shape)
drugs_oral.head()
# Out:
# (360, 21)
#    active_ingredient_moiety nda_bla  approval_year        active DrugBank ID  \
# 0              troglitazone     NDA           1997  troglitazone     DB00197
# 2  anagrelide hydrochloride     NDA           1997    anagrelide     DB00261
# 3       nelfinavir mesylate     NDA           1997    nelfinavir     DB00220
# 4      delavirdine mesylate     NDA           1997   delavirdine     DB00705
# 5  tamsulosin hydrochloride     NDA           1997    tamsulosin     DB00706
#
#                             Drug Groups  \
# 0  approved; investigational; withdrawn
# 2                              approved
# 3                              approved
# 4                              approved
# 5             approved; investigational
#
#                                                                                                       SMILES  \
# 0                                              CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C=C3)O2)C(C)=C1O
# 2                                                                            ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl
# 3  [H][C@@]12CCCC[C@]1([H])CN(C[C@@H](O)[C@H](CSC1=CC=CC=C1)NC(=O)C1=C(C)C(O)=CC=C1)[C@@H](C2)C(=O)NC(C)(C)C
# 4                                         CC(C)NC1=C(N=CC=C1)N1CCN(CC1)C(=O)C1=CC2=C(N1)C=CC(NS(C)(=O)=O)=C2
# 5                                                     CCOC1=CC=CC=C1OCCN[C@H](C)CC1=CC(=C(OC)C=C1)S(N)(=O)=O
#
#            Name          Drug Type  \
# 0  Troglitazone  SmallMoleculeDrug
# 2    Anagrelide  SmallMoleculeDrug
# 3    Nelfinavir  SmallMoleculeDrug
# 4   Delavirdine  SmallMoleculeDrug
# 5    Tamsulosin  SmallMoleculeDrug
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ROMol  \
# 0  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 2  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 3  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 4  <img data-content="rdkit/molecule" src="data:image/png;base64,......
# 5  <img data-content="rdkit/molecule" src="data:image/png;base64,......
#
#    ...          mw  n_hba  n_hbd     logp  route lipinski_mw  lipinski_hbd  \
# 0  ...  441.160994      6      2  4.37426   oral        True          True
# 2  ...  254.996617      3      1  1.92630   oral        True          True
# 3  ...  567.313078      6      4  4.74762   oral       False          True
# 4  ...  456.194360      6      3  2.71710   oral        True          True
# 5  ...  408.171893      6      2  2.34090   oral        True          True
#
#    lipinski_hba  lipinski_logp  n_follow_rules
# 0          True           True               4
# 2          True           True               4
# 3          True           True               3
# 4          True           True               4
# 5          True           True               4
#
# [5 rows x 21 columns]

# %% [markdown]
# There has been 360 FDA approved SMALL drugs with oral admnistration, from 1997 to 2021

# %% [markdown]
# ### 2.6.1) Countplot of the number of rules followed by the structures in the period

# %%
# Setting the plot sizes
sns.set_context("talk", font_scale = 1.6)

fig, ax = plt.subplots(figsize = (15,10))

# The plot
lipinski_plot = sns.countplot(data = drugs_oral, x = "n_follow_rules", color = "#264653").set(title = "FDA approved drugs (1997-2021)", 
                                                                                xlabel = "Number of rules followed", ylabel = "",
                                                                                   ylim = (0,300))
# Title superior to the title plot
fig.suptitle("Distribution of rules followed by the structures (only oral drugs)", fontsize = 32)


# This part of the code is relative to the size of the respective bar of the countplot
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{}'.format(int(y)), (x.mean(), y), 
            ha='center', va='bottom', fontsize = 28) # set the alignment of the text
    
#saving plot
fig.savefig("../imgs/n_follow_rules_countplot_oral.png", dpi=300)

# %%
print(f"{237/361*100:.2f}% of FDA approved drugs with oral admnistration follow all 4 lipinski's rule of 5")
# Out:
# 65.65% of FDA approved drugs with oral admnistration follow all 4 lipinski's rule of 5

# %%
fig, ax = plt.subplots(figsize = (17,15))
sns.set_context("talk", font_scale = 1.8)


names = [0, 1, 2, 3, 4]
num_fol_rule = [3, 6, 50, 65, 237]

plt.pie(num_fol_rule, labels=num_fol_rule, wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, labeldistance = 0.86,
       colors = ["#E09391", "#DEB69B", "#9470E0", "#A6E0BA", "#9EDADE"], textprops={'fontsize': 25})

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle((0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
# legend
plt.legend(title='Number of rules followed', ncol =  5, bbox_to_anchor=(1,0.1), labels = names)

#saving plot
fig.savefig("../imgs/n_follow_rules_donut_oral.png", dpi=300)

# %% [markdown]
# These are the oral drugs that doesn't follow any lipinski rules:

# %%
drugs_oral[drugs_oral["n_follow_rules"] == 0].drop(["ROMol", "Mol_Clean"], axis = 1)
# Out:
#     active_ingredient_moiety nda_bla  approval_year       active DrugBank ID  \
# 43               rifapentine     NDA           1998  rifapentine     DB01201
# 269              fidaxomicin     NDA           2011  fidaxomicin     DB08874
# 455                tenapanor     NDA           2019    tenapanor     DB11761
#
#                    Drug Groups  \
# 43   approved; investigational
# 269                   approved
# 455  approved; investigational
#
#                                                                                                                                                                                                                         SMILES  \
# 43                                                    CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C2=O)C2=C(C(O)=C3C)C(O)=C(NC(=O)\C(C)=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C)C(\C=N\N1CCN(CC1)C1CCCC1)=C2O
# 269  [H][C@@]1(O[C@@H]2[C@@H](CC)\C=C(C)\[C@@H](O)C\C=C\C=C(CO[C@@H]3O[C@H](C)[C@@H](OC(=O)C4=C(CC)C(Cl)=C(O)C(Cl)=C4O)[C@H](O)[C@@H]3OC)\C(=O)O[C@@H](C\C=C(/C)\C=C2/C)[C@@H](C)O)OC(C)(C)[C@@H](OC(=O)C(C)C)[C@H](O)[C@@H]1O
# 455                                                                         CN1C[C@@H](C2=CC(=CC=C2)S(=O)(=O)NCCOCCOCCNC(=O)NCCCCNC(=O)NCCOCCOCCNS(=O)(=O)C2=CC(=CC=C2)[C@@H]2CN(C)CC3=C2C=C(Cl)C=C3Cl)C2=C(C1)C(Cl)=CC(Cl)=C2
#
#             Name          Drug Type           mw  n_hba  n_hbd     logp route  \
# 43   Rifapentine  SmallMoleculeDrug   876.452073     15      6  5.64822  oral
# 269  Fidaxomicin  SmallMoleculeDrug  1056.425221     18      7  6.23440  oral
# 455    Tenapanor  SmallMoleculeDrug  1142.309743     12      6  6.15660  oral
#
#      lipinski_mw  lipinski_hbd  lipinski_hba  lipinski_logp  n_follow_rules
# 43         False         False         False          False               0
# 269        False         False         False          False               0
# 455        False         False         False          False               0

# %% [markdown]
# In comparison we have all the drugs that follow 0 Lipinski's rules (all the dosage forms):

# %%
drugs_db_route_merged[drugs_db_route_merged.n_follow_rules == 0].drop(["ROMol", "Mol_Clean"], axis = 1)
# Out:
#     active_ingredient_moiety nda_bla  approval_year         active  \
# 43               rifapentine     NDA           1998    rifapentine
# 269              fidaxomicin     NDA           2011    fidaxomicin
# 455                tenapanor     NDA           2019      tenapanor
# 524            pafolacianine     NDA           2021  pafolacianine
# 540              trypan blue     NDA           2004    trypan blue
#
#     DrugBank ID                Drug Groups  \
# 43      DB01201  approved; investigational
# 269     DB08874                   approved
# 455     DB11761  approved; investigational
# 524     DB15413  approved; investigational
# 540     DB09158                   approved
#
#                                                                                                                                                                                                                         SMILES  \
# 43                                                    CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C2=O)C2=C(C(O)=C3C)C(O)=C(NC(=O)\C(C)=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C)C(\C=N\N1CCN(CC1)C1CCCC1)=C2O
# 269  [H][C@@]1(O[C@@H]2[C@@H](CC)\C=C(C)\[C@@H](O)C\C=C\C=C(CO[C@@H]3O[C@H](C)[C@@H](OC(=O)C4=C(CC)C(Cl)=C(O)C(Cl)=C4O)[C@H](O)[C@@H]3OC)\C(=O)O[C@@H](C\C=C(/C)\C=C2/C)[C@@H](C)O)OC(C)(C)[C@@H](OC(=O)C(C)C)[C@H](O)[C@@H]1O
# 455                                                                         CN1C[C@@H](C2=CC(=CC=C2)S(=O)(=O)NCCOCCOCCNC(=O)NCCCCNC(=O)NCCOCCOCCNS(=O)(=O)C2=CC(=CC=C2)[C@@H]2CN(C)CC3=C2C=C(Cl)C=C3Cl)C2=C(C1)C(Cl)=CC(Cl)=C2
# 524               CC1(C)\C(=C/C=C2\CCCC(\C=C\C3=[N+](CCCCS(O)(=O)=O)C4=C(C=C(C=C4)S([O-])(=O)=O)C3(C)C)=C2OC2=CC=C(C[C@H](NC(=O)C3=CC=C(NCC4=CN=C5N=C(N)NC(=O)C5=N4)C=C3)C(O)=O)C=C2)N(CCCCS(O)(=O)=O)C2=C1C=C(C=C2)S(O)(=O)=O
# 540                                                                                     CC1=CC(=CC=C1\N=N\C1=C(C=C2C=C(C=C(N)C2=C1O)S(O)(=O)=O)S(O)(=O)=O)C1=CC(C)=C(C=C1)\N=N\C1=C(O)C2=C(N)C=C(C=C2C=C1S(O)(=O)=O)S(O)(=O)=O
#
#                       Name          Drug Type           mw  n_hba  n_hbd  \
# 43             Rifapentine  SmallMoleculeDrug   876.452073     15      6
# 269            Fidaxomicin  SmallMoleculeDrug  1056.425221     18      7
# 455              Tenapanor  SmallMoleculeDrug  1142.309743     12      6
# 524          Pafolacianine  SmallMoleculeDrug  1326.361052     18      9
# 540  Trypan blue free acid  SmallMoleculeDrug   872.054634     16      8
#
#         logp        route  lipinski_mw  lipinski_hbd  lipinski_hba  \
# 43   5.64822         oral        False         False         False
# 269  6.23440         oral        False         False         False
# 455  6.15660         oral        False         False         False
# 524  7.22000  intravenous        False         False         False
# 540  6.67004   ophthalmic        False         False         False
#
#      lipinski_logp  n_follow_rules
# 43           False               0
# 269          False               0
# 455          False               0
# 524          False               0
# 540          False               0

# %% [markdown]
# These are the oral drugs that follow only 1 lipinski rule:

# %%
drugs_oral[drugs_oral["n_follow_rules"] == 1].drop(["ROMol", "Mol_Clean"], axis = 1)
# Out:
#     active_ingredient_moiety nda_bla  approval_year       active DrugBank ID  \
# 156                rifaximin     NDA           2004    rifaximin     DB01220
# 230               everolimus     NDA           2009   everolimus     DB01590
# 290              linaclotide     NDA           2012  linaclotide     DB08890
# 369               venetoclax     NDA           2016   venetoclax     DB11581
# 375              plecanatide     NDA           2017  plecanatide     DB13170
# 431                rifamycin     NDA           2018    rifamycin     DB11753
# 535               icodextrin     NDA           2002   icodextrin     DB00702
#
#                    Drug Groups  \
# 156  approved; investigational
# 230                   approved
# 290                   approved
# 369  approved; investigational
# 375  approved; investigational
# 431  approved; investigational
# 535  approved; investigational
#
#                                                                                                                                                                                                                                                                                                           SMILES  \
# 156                                                                                                                                             CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C)C(O)=C4C(O)=C(NC(=O)\C(C)=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C)C1=C(N=C5C=C(C)C=CN15)C4=C3C2=O
# 230                                                                                        [H][C@@]1(C[C@@H](C)[C@]2([H])CC(=O)[C@H](C)\C=C(C)\[C@@H](O)[C@@H](OC)C(=O)[C@H](C)C[C@H](C)\C=C\C=C\C=C(C)\[C@H](C[C@]3([H])CC[C@@H](C)[C@@](O)(O3)C(=O)C(=O)N3CCCC[C@@]3([H])C(=O)O2)OC)CC[C@@H](OCCO)[C@@H](C1)OC
# 290                                       [H][C@]1(CSSC[C@]2([H])NC(=O)[C@H](CC3=CC=C(O)C=C3)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@@H]3CSSC[C@H](NC(=O)[C@H](C)NC(=O)[C@@H]4CCCN4C(=O)[C@H](CC(N)=O)NC(=O)[C@H](CSSC[C@H](N)C(=O)N3)NC2=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)NCC(=O)N1)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(O)=O
# 369                                                                                                                                                                             CC1(C)CCC(CN2CCN(CC2)C2=CC=C(C(=O)NS(=O)(=O)C3=CC=C(NCC4CCOCC4)C(=C3)[N+]([O-])=O)C(OC3=CN=C4NC=CC4=C3)=C2)=C(C1)C1=CC=C(Cl)C=C1
# 375  [H][C@@]12CSSC[C@H](NC(=O)CNC(=O)[C@@]([H])(NC(=O)[C@]([H])(CSSC[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC(O)=O)NC(=O)[C@@H](N)CC(N)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC(C)C)C(=O)N1)NC(=O)[C@H](C)NC(=O)[C@@H](NC(=O)[C@H](CC(N)=O)NC(=O)[C@@H](NC2=O)C(C)C)C(C)C)[C@@H](C)O)C(=O)N[C@@H](CC(C)C)C(O)=O
# 431                                                                                                                                                             CO[C@H]1\C=C\O[C@@]2(C)OC3=C(C)C(O)=C4C(O)=C(NC(=O)\C(C)=C/C=C/[C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C)C=C(O)C4=C3C2=O
# 535                                                                                                                                                                                        OC[C@H]1OC(O[C@H]2[C@H](O)[C@@H](O)C(O[C@@H]2CO)O[C@H]3[C@H](O)[C@@H](O)[C@@H](O)O[C@@H]3CO)[C@H](O)[C@@H](O)[C@@H]1O
#
#             Name          Drug Type           mw  n_hba  n_hbd     logp route  \
# 156    Rifaximin  SmallMoleculeDrug   785.352359     13      5  6.15784  oral
# 230   Everolimus  SmallMoleculeDrug   957.581356     14      3  6.19720  oral
# 290  Linaclotide  SmallMoleculeDrug  1525.389921     26     19 -5.93920  oral
# 369   Venetoclax  SmallMoleculeDrug   867.318096     11      3  8.65990  oral
# 375  Plecanatide  SmallMoleculeDrug  1680.625199     27     23 -8.14830  oral
# 431    Rifamycin  SmallMoleculeDrug   697.309826     12      6  4.75412  oral
# 535   Icodextrin  SmallMoleculeDrug   504.169035     16     11 -7.57300  oral
#
#      lipinski_mw  lipinski_hbd  lipinski_hba  lipinski_logp  n_follow_rules
# 156        False          True         False          False               1
# 230        False          True         False          False               1
# 290        False         False         False           True               1
# 369        False          True         False          False               1
# 375        False         False         False           True               1
# 431        False         False         False           True               1
# 535        False         False         False           True               1

# %% [markdown]
# These are the drugs that follow only 1 lipinski rule:

# %%
drugs_db_route_merged[drugs_db_route_merged["n_follow_rules"] == 1].drop(["ROMol", "Mol_Clean"], axis = 1)
# Out:
#      active_ingredient_moiety nda_bla  approval_year                active  \
# 23     mangafodipir trisodium     NDA           1997          mangafodipir
# 65          ganirelix acetate     NDA           1999             ganirelix
# 70   epirubicin hydrochloride     NDA           1999            epirubicin
# 71                  sirolimus     NDA           1999             sirolimus
# 96         cetrorelix acetate     NDA           2000            cetrorelix
# 99                bivalirudin     NDA           2000           bivalirudin
# 101       caspofungin acetate     NDA           2001           caspofungin
# 116       fondaparinux sodium     NDA           2001          fondaparinux
# 117              pimecrolimus     NDA           2001          pimecrolimus
# 142                daptomycin     NDA           2003            daptomycin
# 147                  abarelix     NDA           2003              abarelix
# 156                 rifaximin     NDA           2004             rifaximin
# 165                ziconotide     NDA           2004            ziconotide
# 168       pramlintide acetate     NDA           2005           pramlintide
# 169         micafungin sodium     NDA           2005            micafungin
# 171               tigecycline     NDA           2005           tigecycline
# 183             anidulafungin     NDA           2006         anidulafungin
# 200              temsirolimus     NDA           2007          temsirolimus
# 203                lanreotide     NDA           2007            lanreotide
# 227                 degarelix     NDA           2008             degarelix
# 230                everolimus     NDA           2009            everolimus
# 242                telavancin     NDA           2009            telavancin
# 258                  spinosad     NDA           2011              spinosad
# 275                 icatibant     NDA           2011             icatibant
# 290               linaclotide     NDA           2012           linaclotide
# 298               pasireotide     NDA           2012           pasireotide
# 333   oritavancin diphosphate     NDA           2014           oritavancin
# 351                 cangrelor     NDA           2015             cangrelor
# 365                sugammadex     NDA           2015            sugammadex
# 369                venetoclax     NDA           2016            venetoclax
# 375               plecanatide     NDA           2017           plecanatide
# 376             etelcalcetide     NDA           2017         etelcalcetide
# 399               semaglutide     NDA           2017           semaglutide
# 410                plazomicin     NDA           2018            plazomicin
# 431                 rifamycin     NDA           2018             rifamycin
# 443             bremelanotide     NDA           2019         bremelanotide
# 457             afamelanotide     NDA           2019         afamelanotide
# 460               cefiderocol     NDA           2019           cefiderocol
# 494             setmelanotide     NDA           2020         setmelanotide
# 527              eptifibatide     NDA           1998          eptifibatide
# 529       triptorelin pamoate     NDA           2000   triptorelin pamoate
# 535                icodextrin     NDA           2002            icodextrin
# 545      gadoterate meglumine     NDA           2013  gadoterate meglumine
# 547               dalbavancin     NDA           2014           dalbavancin
#
#     DrugBank ID                              Drug Groups  \
# 23      DB06796     approved; investigational; withdrawn
# 65      DB06785                                 approved
# 70      DB00445                                 approved
# 71      DB00877                approved; investigational
# 96      DB00050                approved; investigational
# 99      DB00006                approved; investigational
# 101     DB00520                                 approved
# 116     DB00569                approved; investigational
# 117     DB00337                approved; investigational
# 142     DB00080                approved; investigational
# 147     DB00106     approved; investigational; withdrawn
# 156     DB01220                approved; investigational
# 165     DB06283                                 approved
# 168     DB01278                approved; investigational
# 169     DB01141                approved; investigational
# 171     DB00560                                 approved
# 183     DB00362                approved; investigational
# 200     DB06287                                 approved
# 203     DB06791                                 approved
# 227     DB06699                                 approved
# 230     DB01590                                 approved
# 242     DB06402                                 approved
# 258     DB08823  approved; investigational; vet_approved
# 275     DB06196                approved; investigational
# 290     DB08890                                 approved
# 298     DB06663                                 approved
# 333     DB04911                approved; investigational
# 351     DB06441                                 approved
# 365     DB06206                                 approved
# 369     DB11581                approved; investigational
# 375     DB13170                approved; investigational
# 376     DB12865                approved; investigational
# 399     DB13928                approved; investigational
# 410     DB12615                approved; investigational
# 431     DB11753                approved; investigational
# 443     DB11653                approved; investigational
# 457     DB04931                approved; investigational
# 460     DB14879                approved; investigational
# 494     DB11700                approved; investigational
# 527     DB00063                approved; investigational
# 529     DB06825                   approved; vet approved
# 535     DB00702                approved; investigational
# 545     DB09132                                 approved
# 547     DB06219                approved; investigational
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [Mn++].CC1=C(O)C(CN(CCN(CC([O-])=O)CC2=CC(COP(O)(O)=O)=NC(C)=C2O)CC([O-])=O)=CC(COP(O)(O)=O)=N1
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       CCNC(NCC)=NCCCC[C@@H](NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@@H](CC1=CC=CN=C1)NC(=O)[C@@H](CC1=CC=C(Cl)C=C1)NC(=O)[C@@H](CC1=CC2=CC=CC=C2C=C1)NC(C)=O)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCC
# 101        intravenous        False         False         False
# 116       subcutaneous        False         False         False
# 117            topical        False          True         False
# 142        intravenous        False         False         False
# 147      intramuscular        False         False         False
# 156               oral        False          True         False
# 165        intrathecal        False         False         False
# 168       subcutaneous        False         False         False
# 169        intravenous        False         False         False
# 171        intravenous        False         False         False
# 183        intravenous        False         False         False
# 200        intravenous        False          True         False
# 203       subcutaneous        False         False         False
# 227       subcutaneous        False         False         False
# 230               oral        False          True         False
# 242        intravenous        False         False         False
# 258            topical        False          True         False
# 275       subcutaneous        False         False         False
# 290               oral        False         False         False
# 298     instramuscular        False         False         False
# 333        intravenous        False         False         False
# 351        intravenous        False         False         False
# 365        intravenous        False         False         False
# 369               oral        False          True         False
# 375               oral        False         False         False
# 376        intravenous        False         False         False
# 399  subcutaneous oral        False         False         False
# 410        intravenous        False         False         False
# 431               oral        False         False         False
# 443       subcutaneous        False         False         False
# 457       subcutaneous        False         False         False
# 460        intravenous        False         False         False
# 494       subcutaneous        False         False         False
# 527                NaN        False         False         False
# 529        intravenous        False         False         False
# 535               oral        False         False         False
# 545        intravenous        False         False         False
# 547        intravenous        False         False         False
#
#      lipinski_logp  n_follow_rules
# 23            True               1
# 65            True               1
# 70            True               1
# 71           False               1
# 96            True               1
# 99            True               1
# 101           True               1
# 116           True               1
# 117          False               1
# 142           True               1
# 147           True               1
# 156          False               1
# 165           True               1
# 168           True               1
# 169           True               1
# 171           True               1
# 183           True               1
# 200          False               1
# 203           True               1
# 227           True               1
# 230          False               1
# 242           True               1
# 258          False               1
# 275           True               1
# 290           True               1
# 298           True               1
# 333           True               1
# 351           True               1
# 365           True               1
# 369          False               1
# 375           True               1
# 376           True               1
# 399           True               1
# 410           True               1
# 431           True               1
# 443           True               1
# 457           True               1
# 460           True               1
# 494           True               1
# 527           True               1
# 529           True               1
# 535           True               1
# 545           True               1
# 547           True               1

# %% [markdown]
# ### Analysing the change in each parameter, by year

# %%
drugs_db_route_merged.columns
# Out:
# Index(['active_ingredient_moiety', 'nda_bla', 'approval_year', 'active',
#        'DrugBank ID', 'Drug Groups', 'SMILES', 'Name', 'Drug Type', 'ROMol',
#        'Mol_Clean', 'mw', 'n_hba', 'n_hbd', 'logp', 'route', 'lipinski_mw',
#        'lipinski_hbd', 'lipinski_hba', 'lipinski_logp', 'n_follow_rules'],
#       dtype='object')

# %%
# creating a dataframe that is grouped by year of approval
df_groupby_year = drugs_db_route_merged.groupby("approval_year")
f"The dataset has {df_groupby_year.ngroups} groups"
# Out:
# 'The dataset has 25 groups'

# %%
def change_parameter_name(parameter):
    parameter_change = {"mw": "Molecular Weight",
                        "logp": "Log(P)",
                        "n_hba": "# H-bond Acceptors",
                        "n_hbd": "# H-bond Donors"}
    return parameter_change[parameter]

# %%
def parameter_by_year(parameter, fig, ax):
    # creating a dataset with the mean and median of the parameter in each year
    df_years = pd.DataFrame(columns=["year", f"{parameter}_mean", f"{parameter}_median"])

    for year, df in df_groupby_year:
        df_years.loc[len(df_years)] = [year, df[parameter].mean(), df[parameter].median()]
    
    # creating models with simple linear regression for the mean and median
    X = df_years[["year"]]
    y_mean = df_years[[f"{parameter}_mean"]]
    y_median = df_years[f"{parameter}_median"]
    
    model_mean_lr = LinearRegression().fit(X, y_mean)
    model_median_lr = LinearRegression().fit(X, y_median)
    

    # plotting the mean and median of the parameter by each year
    # color variables
    color1 = '#116530'
    color2 = "#21B6A8"
    
    # plotting mean
    sns.lineplot(x = 'year', y = f"{parameter}_mean", data = df_years, label="mean", color=color1, ax=ax)
    ax.scatter(df_years["year"], df_years[f"{parameter}_mean"], s=250, color=color1)
    
    # plotting median
    sns.lineplot(x = 'year', y = f"{parameter}_median", data = df_years, label="median", color=color2, ax=ax)
    ax.scatter(df_years["year"], df_years[f"{parameter}_median"], s=250, color=color2)
    
    # setting labels
    y_label = change_parameter_name(parameter)
    x_label = "Year"
    ax.set(ylabel=y_label, xlabel=x_label)
    
    # plotting the linear regressions
    ax.plot(X, model_mean_lr.predict(X), color = color1, linestyle = '--', dashes=(8, 5))
    ax.plot(X, model_median_lr.predict(X), color = color2, linestyle = '--', dashes=(8, 5))

# %%
# creating image
fig, axs = plt.subplots(2, 2, figsize = (30,20))

# plotting graphs
parameter_by_year("mw", fig, axs[0][0])
parameter_by_year("logp", fig, axs[0][1])
parameter_by_year("n_hba", fig, axs[1][0])
parameter_by_year("n_hbd", fig, axs[1][1])

# saving img
fig.savefig(f"../imgs/parameters_by_years.png", dpi=300)

# %% [markdown]
# analysing 2005

# %%
drugs_db_route_merged[drugs_db_route_merged["approval_year"] == 2005].drop(["ROMol", "Mol_Clean"], axis = 1)
# Out:
#      active_ingredient_moiety nda_bla  approval_year        active  \
# 168       pramlintide acetate     NDA           2005   pramlintide
# 169         micafungin sodium     NDA           2005    micafungin
# 170                 entecavir     NDA           2005     entecavir
# 171               tigecycline     NDA           2005   tigecycline
# 172                tipranavir     NDA           2005    tipranavir
# 173                 ramelteon     NDA           2005     ramelteon
# 174                 nepafenac     NDA           2005     nepafenac
# 175                nelarabine     NDA           2005    nelarabine
# 176               deferasirox     NDA           2005   deferasirox
# 177        sorafenib tosylate     NDA           2005     sorafenib
# 178              lenalidomide     NDA           2005  lenalidomide
# 179  conivaptan hydrochloride     NDA           2005    conivaptan
#
#     DrugBank ID                Drug Groups  \
# 168     DB01278  approved; investigational
# 169     DB01141  approved; investigational
# 170     DB00442  approved; investigational
# 171     DB00560                   approved
# 172     DB00932  approved; investigational
# 173     DB00980  approved; investigational
# 174     DB06802  approved; investigational
# 175     DB01280  approved; investigational
# 176     DB01609  approved; investigational
# 177     DB00398  approved; investigational
# 178     DB00480                   approved
# 179     DB00872  approved; investigational
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 168  [H]N[C@@H](CCCCN)C(=O)N[C@H]1CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](C)NC(=O)[C@@]([H])(NC(=O)[C@H](CC(N)=O)NC1=O)[C@@H](C)O)[C@@H](C)O)C(=O)N[C@@H](C)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CCC(N)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CN=CN1)C(=O)N[C@@H](CO)C(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](CC1=CC=CC=C1)C(=O)NCC(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)CC)C(=O)N[C@@H](CC(C)C)C(=O)N1CCC[C@H]1C(=O)N1CCC[C@H]1C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@H](C(C)C)C(=O)NCC(=O)N[C@@H](CO)C(=O)N[C@@H](CC(N)=O)C(=O)N[C@@]([H])([C@@H](C)O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(N)=O
# 169                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      CCCCCOC1=CC=C(C=C1)C1=CC(=NO1)C1=CC=C(C=C1)C(=O)N[C@H]1C[C@@H](O)[C@@H](O)NC(=O)[C@@H]2[C@@H](O)[C@@H](C)CN2C(=O)[C@@H](NC(=O)[C@@H](NC(=O)[C@@H]2C[C@@H](O)CN2C(=O)[C@@H](NC1=O)[C@@H](C)O)[C@H](O)[C@@H](O)C1=CC(OS(O)(=O)=O)=C(O)C=C1)[C@H](O)CC(N)=O
# 170                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NC1=NC(=O)C2=C(N1)N(C=N2)[C@H]1C[C@H](O)[C@@H](CO)C1=C
# 171                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [H][C@@]12CC3=C(C(O)=C(NC(=O)CNC(C)(C)C)C=C3N(C)C)C(=O)C1=C(O)[C@]1(O)C(=O)C(C(N)=O)=C(O)[C@@H](N(C)C)[C@]1([H])C2
# 172                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [H][C@@](CC)(C1=CC(NS(=O)(=O)C2=NC=C(C=C2)C(F)(F)F)=CC=C1)C1=C(O)C[C@@](CCC)(CCC2=CC=CC=C2)OC1=O
# 173                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        CCC(=O)NCC[C@@H]1CCC2=C1C1=C(OCC1)C=C2
# 174                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         NC(=O)CC1=CC=CC(C(=O)C2=CC=CC=C2)=C1N
# 175                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      COC1=NC(N)=NC2=C1N=CN2[C@@H]1O[C@H](CO)[C@@H](O)[C@@H]1O
# 176                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        OC(=O)C1=CC=C(C=C1)N1N=C(N=C1C1=CC=CC=C1O)C1=CC=CC=C1O
# 177                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            CNC(=O)C1=NC=CC(OC2=CC=C(NC(=O)NC3=CC(=C(Cl)C=C3)C(F)(F)F)C=C2)=C1
# 178                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NC1=CC=CC2=C1CN(C1CCC(=O)NC1=O)C2=O
# 179                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  CC1=NC2=C(CCN(C(=O)C3=CC=C(NC(=O)C4=CC=CC=C4C4=CC=CC=C4)C=C3)C3=CC=CC=C23)N1
#
#              Name          Drug Type           mw  n_hba  n_hbd      logp  \
# 168   Pramlintide  SmallMoleculeDrug  3946.920674     59     56 -23.82513
# 169    Micafungin  SmallMoleculeDrug  1269.438351     23     16  -3.90200
# 170     Entecavir  SmallMoleculeDrug   277.117489      7      4  -0.82780
# 171   Tigecycline  SmallMoleculeDrug   585.279863     11      7   0.51320
# 172    Tipranavir  SmallMoleculeDrug   602.206228      6      2   7.32550
# 173     Ramelteon  SmallMoleculeDrug   259.157229      2      1   2.56760
# 174     Nepafenac  SmallMoleculeDrug   254.105528      3      2   1.52760
# 175    Nelarabine  SmallMoleculeDrug   297.107319     10      4  -1.97140
# 176   Deferasirox  SmallMoleculeDrug   373.106256      6      3   3.71070
# 177     Sorafenib  SmallMoleculeDrug   464.086303      4      3   5.54970
# 178  Lenalidomide  SmallMoleculeDrug   259.095691      4      2   0.02980
# 179    Conivaptan  SmallMoleculeDrug   498.205576      3      2   6.50732
#
#             route  lipinski_mw  lipinski_hbd  lipinski_hba  lipinski_logp  \
# 168  subcutaneous        False         False         False           True
# 169   intravenous        False         False         False           True
# 170          oral         True          True          True           True
# 171   intravenous        False         False         False           True
# 172          oral        False          True          True          False
# 173          oral         True          True          True           True
# 174    ophthalmic         True          True          True           True
# 175   intravenous         True          True          True           True
# 176          oral         True          True          True           True
# 177          oral         True          True          True          False
# 178          oral         True          True          True           True
# 179   intravenous         True          True          True          False
#
#      n_follow_rules
# 168               1
# 169               1
# 170               4
# 171               1
# 172               2
# 173               4
# 174               4
# 175               4
# 176               4
# 177               3
# 178               4
# 179               3

# %%
drugs_db_route_merged[drugs_db_route_merged["mw"] > 1000].drop(["ROMol", "Mol_Clean"], axis = 1)
# Out:
#     active_ingredient_moiety nda_bla  approval_year               active  \
# 65         ganirelix acetate     NDA           1999            ganirelix
# 96        cetrorelix acetate     NDA           2000           cetrorelix
# 99               bivalirudin     NDA           2000          bivalirudin
# 101      caspofungin acetate     NDA           2001          caspofungin
# 116      fondaparinux sodium     NDA           2001         fondaparinux
# 142               daptomycin     NDA           2003           daptomycin
# 147                 abarelix     NDA           2003             abarelix
# 165               ziconotide     NDA           2004           ziconotide
# 168      pramlintide acetate     NDA           2005          pramlintide
# 169        micafungin sodium     NDA           2005           micafungin
# 183            anidulafungin     NDA           2006        anidulafungin
# 200             temsirolimus     NDA           2007         temsirolimus
# 203               lanreotide     NDA           2007           lanreotide
# 227                degarelix     NDA           2008            degarelix
# 242               telavancin     NDA           2009           telavancin
# 258                 spinosad     NDA           2011             spinosad
# 269              fidaxomicin     NDA           2011          fidaxomicin
# 275                icatibant     NDA           2011            icatibant
# 290              linaclotide     NDA           2012          linaclotide
# 298              pasireotide     NDA           2012          pasireotide
# 333  oritavancin diphosphate     NDA           2014          oritavancin
# 365               sugammadex     NDA           2015           sugammadex
# 375              plecanatide     NDA           2017          plecanatide
# 376            etelcalcetide     NDA           2017        etelcalcetide
# 399              semaglutide     NDA           2017          semaglutide
# 443            bremelanotide     NDA           2019        bremelanotide
# 455                tenapanor     NDA           2019            tenapanor
# 457            afamelanotide     NDA           2019        afamelanotide
# 494            setmelanotide     NDA           2020        setmelanotide
# 500              voclosporin     NDA           2021          voclosporin
# 524            pafolacianine     NDA           2021        pafolacianine
# 529      triptorelin pamoate     NDA           2000  triptorelin pamoate
# 547              dalbavancin     NDA           2014          dalbavancin
#
#     DrugBank ID                              Drug Groups  \
# 65      DB06785                                 approved
# 96      DB00050                approved; investigational
# 99      DB00006                approved; investigational
# 101     DB00520                                 approved
# 116     DB00569                approved; investigational
# 142     DB00080                approved; investigational
# 147     DB00106     approved; investigational; withdrawn
# 165     DB06283                                 approved
# 168     DB01278                approved; investigational
# 169     DB01141                approved; investigational
# 183     DB00362                approved; investigational
# 200     DB06287                                 approved
# 203     DB06791                                 approved
# 227     DB06699                                 approved
# 242     DB06402                                 approved
# 258     DB08823  approved; investigational; vet_approved
# 269     DB08874                                 approved
# 275     DB06196                approved; investigational
# 290     DB08890                                 approved
# 298     DB06663                                 approved
# 333     DB04911                approved; investigational
# 365     DB06206                                 approved
# 375     DB13170                approved; investigational
# 376     DB12865                approved; investigational
# 399     DB13928                approved; investigational
# 443     DB11653                approved; investigational
# 455     DB11761                approved; investigational
# 457     DB04931                approved; investigational
# 494     DB11700                approved; investigational
# 500     DB11693                approved; investigational
# 524     DB15413                approved; investigational
# 529     DB06825                   approved; vet approved
# 547     DB06219                approved; investigational
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            SMILES  \
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       CCNC(NCC)=NCCCC[C@@H](NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@@H](CC1=CC=CN=C1)NC(=O)[C@@H](CC1=CC=C(Cl)C=C1)NC(=O)[C@@H](CC1=CC2=CC=CC=C2C=C1)NC(C)=O)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CCCCN=C(NCC)NCC)C(=O)N1CCC[C@H]1C(=O)N[C@H](C)C(N)=O
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@@H](CC1=CN=CC=C1)NC(=O)[C@@H](CC1=CC=C(Cl)C=C1)NC(=O)[C@@H](CC1=CC2=CC=CC=C2C=C1)NC(C)=O)C(=O)N[C@@H](CCCNC(N)=N)C(=O)N1CCC[C@H]1C(=O)N[C@H](C)C(N)=O
# 99                                                                                                                                                                                                                                                                                                                                                                                                          CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O
# 101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [H][C@@]12C[C@@H](O)CN1C(=O)[C@@H](NC(=O)[C@]([H])(C[C@@H](O)[C@@H](NCCN)NC(=O)[C@@H]1[C@@H](O)CCN1C(=O)[C@@H](NC(=O)[C@@H](NC2=O)[C@H](O)[C@@H](O)C1=CC=C(O)C=C1)[C@H](O)CCN)NC(=O)CCCCCCCC[C@@H](C)C[C@@H](C)CC)[C@@H](C)O
# 116                                                                                                                                                                                                                                                                                                                                                                                                                                                                         CO[C@H]1O[C@H](COS(O)(=O)=O)[C@@H](O[C@@H]2O[C@H]([C@@H](O[C@H]3O[C@H](COS(O)(=O)=O)[C@@H](O[C@@H]4O[C@@H]([C@@H](O[C@H]5O[C@H](COS(O)(=O)=O)[C@@H](O)[C@H](O)[C@H]5NS(O)(=O)=O)[C@H](O)[C@H]4O)C(O)=O)[C@H](OS(O)(=O)=O)[C@H]3NS(O)(=O)=O)[C@H](O)[C@H]2OS(O)(=O)=O)C(O)=O)[C@H](O)[C@H]1NS(O)(=O)=O
# 142                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                CCCCCCCCCC(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)N[C
# 298     instramuscular        False         False         False
# 333        intravenous        False         False         False
# 365        intravenous        False         False         False
# 375               oral        False         False         False
# 376        intravenous        False         False         False
# 399  subcutaneous oral        False         False         False
# 443       subcutaneous        False         False         False
# 455               oral        False         False         False
# 457       subcutaneous        False         False         False
# 494       subcutaneous        False         False         False
# 500               oral        False          True         False
# 524        intravenous        False         False         False
# 529        intravenous        False         False         False
# 547        intravenous        False         False         False
#
#      lipinski_logp  n_follow_rules
# 65            True               1
# 96            True               1
# 99            True               1
# 101           True               1
# 116           True               1
# 142           True               1
# 147           True               1
# 165           True               1
# 168           True               1
# 169           True               1
# 183           True               1
# 200          False               1
# 203           True               1
# 227           True               1
# 242           True               1
# 258          False               1
# 269          False               0
# 275           True               1
# 290           True               1
# 298           True               1
# 333           True               1
# 365           True               1
# 375           True               1
# 376           True               1
# 399           True               1
# 443           True               1
# 455          False               0
# 457           True               1
# 494           True               1
# 500           True               2
# 524          False               0
# 529           True               1
# 547           True               1

# %%
drugs_db_route_merged.columns
# Out:
# Index(['active_ingredient_moiety', 'nda_bla', 'approval_year', 'active',
#        'DrugBank ID', 'Drug Groups', 'SMILES', 'Name', 'Drug Type', 'ROMol',
#        'Mol_Clean', 'mw', 'n_hba', 'n_hbd', 'logp', 'route', 'lipinski_mw',
#        'lipinski_hbd', 'lipinski_hba', 'lipinski_logp', 'n_follow_rules'],
#       dtype='object')

# %%
for year, df in df_groupby_year:
    print(year)
    print(df["n_hba"].mean())
    print(df["mw"].median())
    print("------------------------------")
# Out:
# 1997
# 4.588235294117647
# 367.14859541199996
# ------------------------------
# 1998
# 5.458333333333333
# 347.15800584199997
# ------------------------------
# 1999
# 5.466666666666667
# 352.164196818
# ------------------------------
# 2000
# 6.684210526315789
# 351.034747896
# ------------------------------
# 2001
# 8.15
# 445.20678990199997
# ------------------------------
# 2002
# 5.866666666666666
# 390.2406241879999
# ------------------------------
# 2003
# 7.888888888888889
# 412.601685742
# ------------------------------
# 2004
# 7.68
# 392.0984766040901
# ------------------------------
# 2005
# 11.5
# 418.59627933599995
# ------------------------------
# 2006
# 6.6
# 407.11807942
# ------------------------------
# 2007
# 7.266666666666667
# 506.28144344399993
# ------------------------------
# 2008
# 6.1
# 417.756775774
# ------------------------------
# 2009
# 6.2631578947368425
# 393.12554743199996
# ------------------------------
# 2010
# 7.2727272727272725
# 492.255897392
# ------------------------------
# 2011
# 7.454545454545454
# 445.167509504
# ------------------------------
# 2012
# 6.333333333333333
# 473.08494526600003
# ------------------------------
# 2013
# 6.666666666666667
# 431.178787038
# ------------------------------
# 2014
# 7.458333333333333
# 408.22884411704496
# ------------------------------
# 2015
# 8.115384615384615
# 483.73040133999996
# ------------------------------
# 2016
# 4.428571428571429
# 420.32395988799993
# ------------------------------
# 2017
# 9.172413793103448
# 465.19132297600004
# ------------------------------
# 2018
# 7.0
# 469.16808094000004
# ------------------------------
# 2019
# 6.451612903225806
# 434.0283739162699
# ------------------------------
# 2020
# 7.333333333333333
# 444.216140756
# ------------------------------
# 2021
# 7.576923076923077
# 494.696099768
# ------------------------------
