# %% [markdown]
# # Checking Substructure hits in molecules with known biological activity on Leishmania infantum NAD-dependent protein deacetylase (SIR2RP1)
#
# In this notebook, the molecules with know acitivity for the NAD-dependent protein deacetylase (SIR2RP1), a <em> Leishmania infantum </em> sirtuin, will be downloaded from chembl.
#
# These molecules will be compared with the synthetically tractable fragments from the VEHICLe dataset. Fragments present wthin the molecules with biological activity will be analysed further.

# %%
#Importing Libraries

import math
from pathlib import Path
from zipfile import ZipFile
from tempfile import TemporaryDirectory

from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator
from rdkit.Chem import Descriptors, Draw, PandasTools
from rdkit.ML.Cluster import Butina
import numpy as np
import pandas as pd
from rdkit.Chem import PandasTools
from chembl_webresource_client.new_client import new_client
from tqdm.auto import tqdm

from rdkit.Chem import AllChem

from pathlib import Path

import pandas as pd
from tqdm.auto import tqdm
from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem.FilterCatalog import FilterCatalog, FilterCatalogParams

# %%
#Setting up the Path to save results

HERE = Path(_dh[-1])
DATA = HERE / "DATA"

# %% [markdown]
# ## Downloading Activities from Chembl

# %%
#Link to chembl Target Report Card
#https://www.ebi.ac.uk/chembl/target_report_card/CHEMBL2311240/

chembl_id = "CHEMBL2311240" 

bioactivities = bioactivities_api.filter(
    target_chembl_id=chembl_id, type="IC50", relation="=", assay_type="B"
).only(
    "activity_id",
    "assay_chembl_id",
    "assay_description",
    "assay_type",
    "molecule_chembl_id",
    "type",
    "standard_units",
    "relation",
    "standard_value",
    "target_chembl_id",
    "target_organism",
)

print(f"Number of bioactivities imported: {len(bioactivities)}")
# Out:
# Number of bioactivities imported: 21

# %%
print(f"Length and type of first element: {len(bioactivities[0])}, {type(bioactivities[0])}")
bioactivities[0]
# Out:
# Length and type of first element: 13, <class 'dict'>
# {'activity_id': 12618266,
#  'assay_chembl_id': 'CHEMBL2320160',
#  'assay_description': 'Inhibition of Leishmania infantum SIR2RP1',
#  'assay_type': 'B',
#  'molecule_chembl_id': 'CHEMBL508272',
#  'relation': '=',
#  'standard_units': 'nM',
#  'standard_value': '35200.0',
#  'target_chembl_id': 'CHEMBL2311240',
#  'target_organism': 'Leishmania infantum',
#  'type': 'IC50',
#  'units': 'uM',
#  'value': '35.2'}

# %%
bioactivities_df = pd.DataFrame.from_records(bioactivities)
print(f"DataFrame shape: {bioactivities_df.shape}")
bioactivities_df
# Out:
# DataFrame shape: (22, 13)
#     activity_id assay_chembl_id  \
# 0      12618266   CHEMBL2320160
# 1      12618266   CHEMBL2320160
# 2      12618267   CHEMBL2320160
# 3      12618268   CHEMBL2320160
# 4      12618269   CHEMBL2320160
# 5      12618271   CHEMBL2320160
# 6      18482627   CHEMBL4185229
# 7      18482628   CHEMBL4185229
# 8      18482629   CHEMBL4185229
# 9      18482630   CHEMBL4185229
# 10     18482631   CHEMBL4185229
# 11     18482632   CHEMBL4185229
# 12     18482633   CHEMBL4185229
# 13     18482634   CHEMBL4185229
# 14     18482635   CHEMBL4185229
# 15     18482636   CHEMBL4185229
# 16     18482637   CHEMBL4185229
# 17     18482638   CHEMBL4185229
# 18     18482639   CHEMBL4185229
# 19     18482640   CHEMBL4185229
# 20     18482641   CHEMBL4185229
# 21     18482642   CHEMBL4185229
#
#                                     assay_description assay_type  \
# 0           Inhibition of Leishmania infantum SIR2RP1          B
# 1           Inhibition of Leishmania infantum SIR2RP1          B
# 2           Inhibition of Leishmania infantum SIR2RP1          B
# 3           Inhibition of Leishmania infantum SIR2RP1          B
# 4           Inhibition of Leishmania infantum SIR2RP1          B
# 5           Inhibition of Leishmania infantum SIR2RP1          B
# 6   Inhibition of N-terminal His6-tagged recombina...          B
# 7   Inhibition of N-terminal His6-tagged recombina...          B
# 8   Inhibition of N-terminal His6-tagged recombina...          B
# 9   Inhibition of N-terminal His6-tagged recombina...          B
# 10  Inhibition of N-terminal His6-tagged recombina...          B
# 11  Inhibition of N-terminal His6-tagged recombina...          B
# 12  Inhibition of N-terminal His6-tagged recombina...          B
# 13  Inhibition of N-terminal His6-tagged recombina...          B
# 14  Inhibition of N-terminal His6-tagged recombina...          B
# 15  Inhibition of N-terminal His6-tagged recombina...          B
# 16  Inhibition of N-terminal His6-tagged recombina...          B
# 17  Inhibition of N-terminal His6-tagged recombina...          B
# 18  Inhibition of N-terminal His6-tagged recombina...          B
# 19  Inhibition of N-terminal His6-tagged recombina...          B
# 20  Inhibition of N-terminal His6-tagged recombina...          B
# 21  Inhibition of N-terminal His6-tagged recombina...          B
#
#    molecule_chembl_id relation standard_units standard_value target_chembl_id  \
# 0        CHEMBL508272        =             nM        35200.0    CHEMBL2311240
# 1        CHEMBL508272        =             nM        35200.0    CHEMBL2311240
# 2        CHEMBL228002        =             nM         5700.0    CHEMBL2311240
# 3        CHEMBL228067        =             nM         9200.0    CHEMBL2311240
# 4        CHEMBL380797        =             nM       193800.0    CHEMBL2311240
# 5          CHEMBL1140        =             nM        39400.0    CHEMBL2311240
# 6        CHEMBL380797        =             nM       194000.0    CHEMBL2311240
# 7          CHEMBL1140        =             nM        40000.0    CHEMBL2311240
# 8       CHEMBL4216559        =             nM         5700.0    CHEMBL2311240
# 9       CHEMBL3040216        =             nM         7000.0    CHEMBL2311240
# 10      CHEMBL4211052        =             nM         5700.0    CHEMBL2311240
# 11      CHEMBL4204117        =             nM         5700.0    CHEMBL2311240
# 12      CHEMBL4215363        =             nM         5700.0    CHEMBL2311240
# 13      CHEMBL4206570        =             nM         5700.0    CHEMBL2311240
# 14      CHEMBL4211460        =             nM         5700.0    CHEMBL2311240
# 15      CHEMBL4214749        =             nM         5700.0    CHEMBL2311240
# 16      CHEMBL4209842        =             nM         5700.0    CHEMBL2311240
# 17      CHEMBL4217062        =             nM         5700.0    CHEMBL2311240
# 18      CHEMBL4205463        =             nM         5700.0    CHEMBL2311240
# 19      CHEMBL4205986        =             nM         5700.0    CHEMBL2311240
# 20      CHEMBL4217704        =             nM         5700.0    CHEMBL2311240
# 21      CHEMBL4218232        =             nM         5700.0    CHEMBL2311240
#
#         target_organism  type units  value
# 0   Leishmania infantum  IC50    uM   35.2
# 1   Leishmania infantum  IC50    uM   35.2
# 2   Leishmania infantum  IC50    uM    5.7
# 3   Leishmania infantum  IC50    uM    9.2
# 4   Leishmania infantum  IC50    uM  193.8
# 5   Leishmania infantum  IC50    uM   39.4
# 6   Leishmania infantum  IC50    uM  194.0
# 7   Leishmania infantum  IC50    uM   40.0
# 8   Leishmania infantum  IC50    uM    5.7
# 9   Leishmania infantum  IC50    uM    7.0
# 10  Leishmania infantum  IC50    uM    5.7
# 11  Leishmania infantum  IC50    uM    5.7
# 12  Leishmania infantum  IC50    uM    5.7
# 13  Leishmania infantum  IC50    uM    5.7
# 14  Leishmania infantum  IC50    uM    5.7
# 15  Leishmania infantum  IC50    uM    5.7
# 16  Leishmania infantum  IC50    uM    5.7
# 17  Leishmania infantum  IC50    uM    5.7
# 18  Leishmania infantum  IC50    uM    5.7
# 19  Leishmania infantum  IC50    uM    5.7
# 20  Leishmania infantum  IC50    uM    5.7
# 21  Leishmania infantum  IC50    uM    5.7

# %% [markdown]
# ## Cleaning the data set

# %%
#Selecting only relevant collumns

bioactivities_df = bioactivities_df[['activity_id', 'assay_chembl_id', 'assay_description', 'molecule_chembl_id', 
                                     'standard_units', 'standard_value', 'type']]

# %%
#Checking varible types
bioactivities_df.dtypes
# Out:
# activity_id            int64
# assay_chembl_id       object
# assay_description     object
# molecule_chembl_id    object
# standard_units        object
# standard_value        object
# type                  object
# dtype: object

# %%
#Converting activities to float
bioactivities_df = bioactivities_df.astype({"standard_value": "float64"})
bioactivities_df.dtypes
# Out:
# activity_id             int64
# assay_chembl_id        object
# assay_description      object
# molecule_chembl_id     object
# standard_units         object
# standard_value        float64
# type                   object
# dtype: object

# %%
#Dropping duplicates
bioactivities_df.drop_duplicates("molecule_chembl_id", keep="first", inplace=True)
print(f"DataFrame shape: {bioactivities_df.shape}")
# Out:
# DataFrame shape: (19, 7)

# %%
#reset index
bioactivities_df.reset_index(drop=True, inplace=True)
bioactivities_df.head()
# Out:
#    activity_id assay_chembl_id                          assay_description  \
# 0     12618266   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 1     12618267   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 2     12618268   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 3     12618269   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 4     12618271   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
#
#   molecule_chembl_id standard_units  standard_value  type
# 0       CHEMBL508272             nM         35200.0  IC50
# 1       CHEMBL228002             nM          5700.0  IC50
# 2       CHEMBL228067             nM          9200.0  IC50
# 3       CHEMBL380797             nM        193800.0  IC50
# 4         CHEMBL1140             nM         39400.0  IC50

# %%
#renaming collumns
bioactivities_df.rename(
    columns={"standard_value": "IC50", "standard_units": "units"}, inplace=True
)
bioactivities_df.head()
# Out:
#    activity_id assay_chembl_id                          assay_description  \
# 0     12618266   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 1     12618267   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 2     12618268   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 3     12618269   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
# 4     12618271   CHEMBL2320160  Inhibition of Leishmania infantum SIR2RP1
#
#   molecule_chembl_id units      IC50  type
# 0       CHEMBL508272    nM   35200.0  IC50
# 1       CHEMBL228002    nM    5700.0  IC50
# 2       CHEMBL228067    nM    9200.0  IC50
# 3       CHEMBL380797    nM  193800.0  IC50
# 4         CHEMBL1140    nM   39400.0  IC50

# %%
#Removing molecules with IC50 above 10.000 nM
bioactivities_df = bioactivities_df[bioactivities_df['IC50'] < 10000]
bioactivities_df
# Out:
#     activity_id assay_chembl_id  \
# 1      12618267   CHEMBL2320160
# 2      12618268   CHEMBL2320160
# 5      18482629   CHEMBL4185229
# 6      18482630   CHEMBL4185229
# 7      18482631   CHEMBL4185229
# 8      18482632   CHEMBL4185229
# 9      18482633   CHEMBL4185229
# 10     18482634   CHEMBL4185229
# 11     18482635   CHEMBL4185229
# 12     18482636   CHEMBL4185229
# 13     18482637   CHEMBL4185229
# 14     18482638   CHEMBL4185229
# 15     18482639   CHEMBL4185229
# 16     18482640   CHEMBL4185229
# 17     18482641   CHEMBL4185229
# 18     18482642   CHEMBL4185229
#
#                                     assay_description molecule_chembl_id  \
# 1           Inhibition of Leishmania infantum SIR2RP1       CHEMBL228002
# 2           Inhibition of Leishmania infantum SIR2RP1       CHEMBL228067
# 5   Inhibition of N-terminal His6-tagged recombina...      CHEMBL4216559
# 6   Inhibition of N-terminal His6-tagged recombina...      CHEMBL3040216
# 7   Inhibition of N-terminal His6-tagged recombina...      CHEMBL4211052
# 8   Inhibition of N-terminal His6-tagged recombina...      CHEMBL4204117
# 9   Inhibition of N-terminal His6-tagged recombina...      CHEMBL4215363
# 10  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4206570
# 11  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4211460
# 12  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4214749
# 13  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4209842
# 14  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4217062
# 15  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4205463
# 16  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4205986
# 17  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4217704
# 18  Inhibition of N-terminal His6-tagged recombina...      CHEMBL4218232
#
#    units    IC50  type
# 1     nM  5700.0  IC50
# 2     nM  9200.0  IC50
# 5     nM  5700.0  IC50
# 6     nM  7000.0  IC50
# 7     nM  5700.0  IC50
# 8     nM  5700.0  IC50
# 9     nM  5700.0  IC50
# 10    nM  5700.0  IC50
# 11    nM  5700.0  IC50
# 12    nM  5700.0  IC50
# 13    nM  5700.0  IC50
# 14    nM  5700.0  IC50
# 15    nM  5700.0  IC50
# 16    nM  5700.0  IC50
# 17    nM  5700.0  IC50
# 18    nM  5700.0  IC50

# %% [markdown]
# ## Getting compound data

# %%
#getting compound data from chembl
compounds_provider = compounds_api.filter(
    molecule_chembl_id__in=list(bioactivities_df["molecule_chembl_id"])
).only("molecule_chembl_id", "molecule_structures")

# %%
compounds = list(tqdm(compounds_provider))
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
#transforming to dataframe
compounds_df = pd.DataFrame.from_records(
    compounds,
)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (16, 2)

# %%
compounds_df.head()
# Out:
#   molecule_chembl_id                                molecule_structures
# 0       CHEMBL228067  {'canonical_smiles': 'O=C1c2cccc3cccc(c23)C(=O...
# 1       CHEMBL228002  {'canonical_smiles': 'O=C1c2cccc3cccc(c23)C(=O...
# 2      CHEMBL3040216  {'canonical_smiles': 'CC1=CCC(C(=O)/N=C2\CC=C(...
# 3      CHEMBL4204117  {'canonical_smiles': 'Br.Br.O=C1c2cccc3cccc(c2...
# 4      CHEMBL4205463  {'canonical_smiles': 'Br.Br.Br.O=C1c2cccc3cccc...

# %%
#drop na
compounds_df.dropna(axis=0, how="any", inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (16, 2)

# %%
#Checking available molecule structure formats 
compounds_df.iloc[0].molecule_structures.keys()
# Out:
# dict_keys(['canonical_smiles', 'molfile', 'standard_inchi', 'standard_inchi_key'])

# %%
#selecting molecules SMILES

canonical_smiles = []

for i, compounds in compounds_df.iterrows():
    try:
        canonical_smiles.append(compounds["molecule_structures"]["canonical_smiles"])
    except KeyError:
        canonical_smiles.append(None)

compounds_df["smiles"] = canonical_smiles
compounds_df.drop("molecule_structures", axis=1, inplace=True)
print(f"DataFrame shape: {compounds_df.shape}")
# Out:
# DataFrame shape: (16, 2)

# %%
#Drawing molecules

PandasTools.AddMoleculeColumnToFrame(compounds_df, "smiles")
compounds_df
# Out:
#    molecule_chembl_id                                             smiles  \
# 0        CHEMBL228067  O=C1c2cccc3cccc(c23)C(=O)N1CCCNCCCCCCCCNCCCN1C...
# 1        CHEMBL228002  O=C1c2cccc3cccc(c23)C(=O)N1CCCNCCCCCCCCCNCCCN1...
# 2       CHEMBL3040216  CC1=CCC(C(=O)/N=C2\CC=C(S(=O)(=O)O)c3cc(S(=O)(...
# 3       CHEMBL4204117  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCNCCN1...
# 4       CHEMBL4205463  Br.Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCNCC...
# 5       CHEMBL4205986  Br.Br.Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCN...
# 6       CHEMBL4206570  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCCCNCC...
# 7       CHEMBL4209842  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCCCCCC...
# 8       CHEMBL4211052  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCNCCN1C...
# 9       CHEMBL4211460  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCCCCNC...
# 10      CHEMBL4214749  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCCCCCN...
# 11      CHEMBL4215363  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCCNCCN...
# 12      CHEMBL4216559  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCCNCCCCCCCCC...
# 13      CHEMBL4217062  Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCCCCCCCC...
# 14      CHEMBL4217704  Br.Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCCNCCC...
# 15      CHEMBL4218232  Br.Br.Br.O=C1c2cccc3cccc(c23)C(=O)N1CCNCCNCCNC...
#
#                                                 ROMol
# 0   <img data-content="rdkit/molecule" src="data:i...
# 1   <img data-content="rdkit/molecule" src="data:i...
# 2   <img data-content="rdkit/molecule" src="data:i...
# 3   <img data-content="rdkit/molecule" src="data:i...
# 4   <img data-content="rdkit/molecule" src="data:i...
# 5   <img data-content="rdkit/molecule" src="data:i...
# 6   <img data-content="rdkit/molecule" src="data:i...
# 7   <img data-content="rdkit/molecule" src="data:i...
# 8   <img data-content="rdkit/molecule" src="data:i...
# 9   <img data-content="rdkit/molecule" src="data:i...
# 10  <img data-content="rdkit/molecule" src="data:i...
# 11  <img data-content="rdkit/molecule" src="data:i...
# 12  <img data-content="rdkit/molecule" src="data:i...
# 13  <img data-content="rdkit/molecule" src="data:i...
# 14  <img data-content="rdkit/molecule" src="data:i...
# 15  <img data-content="rdkit/molecule" src="data:i...

# %%
#Draw mol to grid
#draw grid of molecules 
Draw.MolsToGridImage(
    list(compounds_df['ROMol']),
    molsPerRow=2,
    subImgSize=(600,300)
)

# %% [markdown]
# ## Selecting synthesizable molecules from VEHICLe dataset

# %%
#Importing VEHICLe datgaset
URL = 'https://raw.githubusercontent.com/arturcgs/steel_project/main/data_exploration/VEHICLe.csv'
VEHICLe = pd.read_csv(URL)
VEHICLe.shape
# Out:
# (24867, 6)

# %%
#selecting molecules with p(good) above or equal 0.90
VEHICLe_good = VEHICLe[VEHICLe['Pgood'] >= 0.9].copy()
VEHICLe_good.shape
# Out:
# (3593, 6)

# %%
#Draw Mol molecules
PandasTools.AddMoleculeColumnToFrame(VEHICLe_good, "Smiles")
VEHICLe_good
# Out:
#         Regid                Smiles  Training_dataset_hits  \
# 0          S1            c1cc[nH]c1                  81848
# 1         S10            c1c[nH]nn1                   7925
# 2        S100          O=C1C=CSC=C1                      7
# 21     S10016   O=C1NN=Cc2c[nH]cc12                     22
# 22     S10017      O=C1NN=Cc2cocc12                     10
# ...       ...                   ...                    ...
# 24804   S9942  O=C1NC(=O)c2nnncc2S1                      0
# 24812    S995     O=C1Oc2ccsc2SC1=O                      0
# 24823    S996     O=C1Oc2sccc2SC1=O                      0
# 24852   S9986       O=C1Sc2cnnnc2S1                      0
# 24856    S999        O=C1Sc2ccsc2S1                      0
#
#        Beilstein_hits_June_08  Pgood  Tautomer_cluster  \
# 0                         NaN   0.99               NaN
# 1                         NaN   0.98               2.0
# 2                       375.0   0.92               NaN
# 21                       37.0   0.98               NaN
# 22                        5.0   0.98               NaN
# ...                       ...    ...               ...
# 24804                     0.0   0.92               NaN
# 24812                     0.0   0.92               NaN
# 24823                     0.0   0.92               NaN
# 24852                     0.0   0.93               NaN
# 24856                     9.0   0.94               NaN
#
#                                                    ROMol
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 21     <img data-content="rdkit/molecule" src="data:i...
# 22     <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 24804  <img data-content="rdkit/molecule" src="data:i...
# 24812  <img data-content="rdkit/molecule" src="data:i...
# 24823  <img data-content="rdkit/molecule" src="data:i...
# 24852  <img data-content="rdkit/molecule" src="data:i...
# 24856  <img data-content="rdkit/molecule" src="data:i...
#
# [3593 rows x 7 columns]

# %% [markdown]
# ## Checking substructure hits

# %%
# search for unwanted substructure
matches = []
clean = []
for index, row in tqdm(compounds_df.iterrows(), total=compounds_df.shape[0]):
    molecule = Chem.MolFromSmiles(row.smiles)
    match = False
    for _, substructure in VEHICLe_good.iterrows():
        if molecule.HasSubstructMatch(substructure.ROMol):
            matches.append(
                {
                    "chembl_id": row.molecule_chembl_id,
                    "rdkit_molecule": molecule,
                    "substructure": substructure.ROMol,
                    "substructure_name": substructure["Regid"],
                }
            )
            match = True
    if not match:
        clean.append(index)

matches = pd.DataFrame(matches)
compounds_df = compounds_df.loc[clean]
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
# NBVAL_CHECK_OUTPUT
print(f"Number of found substructure hits: {len(matches)}")
print(f"Number of compounds without substructure hits: {len(compounds_df)}")
# Out:
# Number of found substructure hits: 31
# Number of compounds without substructure hits: 0

# %%
to_highlight = [
    row.rdkit_molecule.GetSubstructMatch(row.substructure) for _, row in matches.head(31).iterrows()
]
Chem.Draw.MolsToGridImage(
    list(matches.head(31).rdkit_molecule),
    highlightAtomLists=to_highlight,
    legends=list(matches.head(31).substructure_name),
    molsPerRow=2,
    subImgSize=(600,300)    
)

# %%
# NBVAL_CHECK_OUTPUT
groups = matches.groupby("substructure_name")
group_frequencies = groups.size()
group_frequencies.sort_values(ascending=False, inplace=True)
group_frequencies.head(10)
# Out:
# substructure_name
# S48      16
# S7958    15
# dtype: int64
