# %% [markdown]
# ## <a id='toc1_1_'></a>[Merging the curated data](#toc0_)
# In this dataset we are going to concatenate the two datasets we did the manual curation earlier into the main dataset.

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
#   - [Importing datasets:](#toc1_2_)
#   - [Concatenate](#toc1_3_)
#   - [Saving the dataset](#toc1_4_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_2_'></a>[Importing datasets:](#toc0_)

# %%
# Importing libraries
import pandas as pd
import session_info

# %%
# We need to import three datasets:
main_df = pd.read_csv('../data/pre_manual_curation/main_df.csv')
manual_fragments = pd.read_csv('../data/manual_curated_datasets/curated_fragments.csv')
manual_smiles_year = pd.read_csv('../data/manual_curated_datasets/curated_smiles_year.csv')

# %%
main_df.query("pref_name == 'MESNA'")
# Out:
#    pref_name         SMILES molecule_chembl_id  first_approval  \
# 39     MESNA  O=S(=O)(O)CCS      CHEMBL1098319            1988
#
#      molecule_type   indication_class  polymer_flag  withdrawn_flag  \
# 39  Small molecule  Detoxifying Agent             0           False
#
#     inorganic_flag  therapeutic_flag  natural_product  oral  parenteral  \
# 39               0              True                0  True        True
#
#     topical          mw
# 39    False  141.975836

# %%
main_df.iloc[39, 1]
# Out:
# 'O=S(=O)(O)CCS'

# %%
print("Main dataframe columns: \n",main_df.shape,main_df.columns,"\n")
print("Manual fragments columns: \n",manual_fragments.shape,manual_fragments.columns,"\n")
print("Manual smiles and year columns: \n",manual_smiles_year.shape,manual_smiles_year.columns,"\n")
# Out:
# Main dataframe columns:
#  (2047, 15) Index(['pref_name', 'SMILES', 'molecule_chembl_id', 'first_approval',
#        'molecule_type', 'indication_class', 'polymer_flag', 'withdrawn_flag',
#        'inorganic_flag', 'therapeutic_flag', 'natural_product', 'oral',
#        'parenteral', 'topical', 'mw'],
#       dtype='object')
#
# Manual fragments columns:
#  (341, 15) Index(['pref_name', 'SMILES', 'molecule_chembl_id', 'first_approval',
#        'molecule_type', 'indication_class', 'polymer_flag', 'withdrawn_flag',
#        'inorganic_flag', 'therapeutic_flag', 'natural_product', 'oral',
#        'parenteral', 'topical', 'mw'],
#       dtype='object')
#
# Manual smiles and year columns:
#  (436, 15) Index(['pref_name', 'SMILES', 'molecule_chembl_id', 'first_approval',
#        'molecule_type', 'indication_class', 'polymer_flag', 'withdrawn_flag',
#        'inorganic_flag', 'therapeutic_flag', 'natural_product', 'oral',
#        'parenteral', 'topical', 'mw'],
#       dtype='object')

# %%
main_df.head(3)
# Out:
#               pref_name    SMILES molecule_chembl_id  first_approval  \
# 0  ACETOHYDROXAMIC ACID  CC(=O)NO          CHEMBL734            1983
# 1           HYDROXYUREA  NC(=O)NO          CHEMBL467            1967
# 2            CYSTEAMINE      NCCS          CHEMBL602            1994
#
#     molecule_type                  indication_class  polymer_flag  \
# 0  Small molecule         Enzyme Inhibitor (urease)             0
# 1  Small molecule                    Antineoplastic             0
# 2  Small molecule  Anti-Urolithic (cystine calculi)             0
#
#    withdrawn_flag  inorganic_flag  therapeutic_flag  natural_product  oral  \
# 0           False               0              True                0  True
# 1           False               0              True                0  True
# 2           False               0              True                0  True
#
#    parenteral  topical         mw
# 0       False    False  75.032028
# 1       False    False  76.027277
# 2       False     True  77.029920

# %%
manual_fragments.head(3)
# Out:
#              pref_name                      SMILES molecule_chembl_id  \
# 0       MERCAPTOPURINE     O.S=c1[nH]cnc2nc[nH]c12      CHEMBL1200751
# 1            CARBACHOL  C[N+](C)(C)CCOC(N)=O.[Cl-]           CHEMBL14
# 2  AMPHETAMINE SULFATE  CC(N)Cc1ccccc1.O=S(=O)(O)O          CHEMBL501
#
#    first_approval   molecule_type          indication_class  polymer_flag  \
# 0          1953.0  Small molecule            Antineoplastic             0
# 1          1972.0  Small molecule  Cholinergic (ophthalmic)             0
# 2          1960.0  Small molecule       Stimulant (central)             0
#
#    withdrawn_flag  inorganic_flag  therapeutic_flag  natural_product   oral  \
# 0           False               0              True                0   True
# 1           False               0              True                0  False
# 2           False               0              True                0   True
#
#    parenteral  topical          mw
# 0       False    False  170.026232
# 1        True    False  182.082205
# 2       False    False  233.072179

# %%
manual_smiles_year.head(3)
# Out:
#                pref_name                                             SMILES  \
# 0  BISMUTH SUBSALICYLATE                          O[Bi]1OC(=O)C2=CC=CC=C2O1
# 1            CARBOPLATIN  [H][N]([H])([H])[Pt]1(OC(=O)C2(CCC2)C(=O)O1)[N...
# 2        AUROTHIOGLUCOSE     OC[C@H]1O[C@H](S[Au])[C@H](O)[C@@H](O)[C@@H]1O
#
#   molecule_chembl_id first_approval   molecule_type  \
# 0         CHEMBL1120         1939.0  Small molecule
# 1         CHEMBL1351         1989.0  Small molecule
# 2      CHEMBL2354773      not found  Small molecule
#
#                           indication_class  polymer_flag  withdrawn_flag  \
# 0  Antidiarrheal; Anti-Ulcerative; Antacid             0           False
# 1                           Antineoplastic             0           False
# 2                     Rheumatoid Arthritis             0           False
#
#    inorganic_flag  therapeutic_flag  natural_product   oral  parenteral  \
# 0               0              True                0   True       False
# 1               0              True                0  False        True
# 2               0              True                1  False       False
#
#    topical   mw
# 0    False  NaN
# 1    False  NaN
# 2    False  NaN

# %% [markdown]
# ## <a id='toc1_3_'></a>[Concatenate](#toc0_)

# %%
dataset_list = [main_df, manual_fragments, manual_smiles_year]
final_df = pd.concat(dataset_list)

print(f"The previous datasets shapes: \nMain df: {main_df.shape}\nManual fragments: {manual_fragments.shape}\nManual Smiles and Year: {manual_smiles_year.shape}\n")
print("After concatenating the final shape is:",(main_df.shape[0]+manual_fragments.shape[0]+manual_smiles_year.shape[0]))

print("Final shape:", final_df.shape)
# Out:
# The previous datasets shapes:
# Main df: (2047, 15)
# Manual fragments: (341, 15)
# Manual Smiles and Year: (436, 15)
#
# After concatenating the final shape is: 2824
# Final shape: (2824, 15)

# %%
#Reseting index
final_df = final_df.reset_index(drop=True)

#Dropping molecular weight to be calculated only afterwards
final_df.drop(["mw"], axis=1)
# Out:
#                  pref_name                                             SMILES  \
# 0     ACETOHYDROXAMIC ACID                                           CC(=O)NO
# 1              HYDROXYUREA                                           NC(=O)NO
# 2               CYSTEAMINE                                               NCCS
# 3       DIMETHYL SULFOXIDE                                       C[S+](C)[O-]
# 4               FOMEPIZOLE                                        Cc1cn[nH]c1
# ...                    ...                                                ...
# 2819     VINDESINE SULFATE  CC[C@]1(O)C[C@@H]2CN(CCc3c([nH]c4ccccc34)[C@@]...
# 2820   CYCLOGUANIL PAMOATE  CC1(C)N=C(N)N=C(N)N1c1ccc(Cl)cc1.CC1(C)N=C(N)N...
# 2821           LENACAPAVIR  CC(C)(C#Cc1ccc(-c2ccc(Cl)c3c(NS(C)(=O)=O)nn(CC...
# 2822          LANATOSIDE C  CC(=O)O[C@H]1C[C@H](O[C@H]2[C@@H](O)C[C@H](O[C...
# 2823           MIFAMURTIDE  CCCCCCCCCCCCCCCC(=O)OC[C@H](COP(=O)(O)OCCNC(=O...
#
#      molecule_chembl_id first_approval   molecule_type  \
# 0             CHEMBL734           1983  Small molecule
# 1             CHEMBL467           1967  Small molecule
# 2             CHEMBL602           1994  Small molecule
# 3             CHEMBL504           1978  Small molecule
# 4            CHEMBL1308           1997  Small molecule
# ...                 ...            ...             ...
# 2819      CHEMBL3989543      not found  Small molecule
# 2820      CHEMBL3989825      not found  Small molecule
# 2821      CHEMBL4594438         2022.0  Small molecule
# 2822       CHEMBL506569      not found  Small molecule
# 2823      CHEMBL2111100      not found  Small molecule
#
#                                 indication_class  polymer_flag  \
# 0                      Enzyme Inhibitor (urease)             0
# 1                                 Antineoplastic             0
# 2               Anti-Urolithic (cystine calculi)             0
# 3                    Anti-Inflammatory (topical)             0
# 4     Antidote (alcohol dehydrogenase inhibitor)             0
# ...                                          ...           ...
# 2819                              Antineoplastic             0
# 2820                                         NaN             0
# 2821                              Antiretroviral             0
# 2822                                         NaN             0
# 2823                                         NaN             0
#
#       withdrawn_flag  inorganic_flag  therapeutic_flag  natural_product  \
# 0              False               0              True                0
# 1              False               0              True                0
# 2              False               0              True                0
# 3              False               0              True                0
# 4              False               0              True                0
# ...              ...             ...               ...              ...
# 2819           False               0              True                1
# 2820           False               0              True                0
# 2821           False               0              True                0
# 2822           False               0              True                1
# 2823           False               0              True                1
#
#        oral  parenteral  topical
# 0      True       False    False
# 1      True       False    False
# 2      True       False     True
# 3     False        True    False
# 4     False        True    False
# ...     ...         ...      ...
# 2819  False       False    False
# 2820   True       False    False
# 2821   True       False    False
# 2822  False       False    False
# 2823  False       False    False
#
# [2824 rows x 14 columns]

# %% [markdown]
# ## <a id='toc1_4_'></a>[Saving the dataset](#toc0_)

# %%
final_df.to_csv("../data/manual_curated_datasets/concatenated_dataset.csv", index=False)

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# pandas              1.5.3
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# asttokens           NA
# backcall            0.2.0
# colorama            0.4.6
# comm                0.1.3
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.6
# decorator           5.1.1
# executing           1.2.0
# google              NA
# importlib_metadata  NA
# ipykernel           6.22.0
# ipython_genutils    0.2.0
# ipywidgets          7.7.2
# jedi                0.18.2
# jupyter_server      2.5.0
# mpl_toolkits        NA
# numexpr             2.8.3
# numpy               1.23.5
# packaging           23.0
# parso               0.8.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.2.0
# prompt_toolkit      3.0.38
# psutil              5.9.4
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.14.0
# pytz                2023.3
# six                 1.16.0
# stack_data          0.6.2
# tornado             6.2
# traitlets           5.9.0
# typing_extensions   NA
# wcwidth             0.2.6
# zipp                NA
# zmq                 25.0.2
# zope                NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.0
# jupyter_client      8.1.0
# jupyter_core        5.3.0
# jupyterlab          3.5.2
# notebook            6.5.3
# -----
# Python 3.8.16 | packaged by conda-forge | (default, Feb  1 2023, 16:01:55) [GCC 11.3.0]
# Linux-6.1.27-1-lts-x86_64-with-glibc2.10
# -----
# Session information updated at 2023-05-10 11:30
# </pre>
# </details>
